# %% [markdown]
# ### HyperText Transfer Protocol: HTML 문서 등의 리소스를 전송하는 프로토콜
#
# 클라이언트  ->(HTTP 요청 (GET, POST 등))  서버
#
# 클라이언트 <- (HTTP응답)                  서버

# %% [markdown]
# ### Get 요청 : 데이터를 URL에 포함아혀 전달(주로 리소스 요청에 사용)
#
# ### Post 요청: 데이터를 Form data에 포함하여 전달(주로 로그인에 사용)

# %% [markdown]
# ### HTML (Hyper Text Markup Language)
#    - 웹사이트를 생성하기 위한 언어로 문서와 문서가 링크로 연결되어 있고, 태그를 사용하는 언어

# %% [markdown]
# ### HTML 문서의 기본 블락
#
# 브라우저에게 어떻게 렌더링(화면에 표시)될지 전달
#
# <태그명 속성1="속성값1" 속성2="속성값2">Value</태그명>
# <태그명 속성1="속성값1" 속성2="속성값2/">

# %% [markdown]
# ### request 모듈
#    1. http request/response를 위한 모듈
#    2. HTTP method를 메소드 명으로 사용하여 request 요청 예) get, post

# %%
import requests

# %% [markdown]
# ### get 요청받기
#    1. http get 요청하기
#    2. query parameter 이용하여 데어터 전달하기

# %%
url = 'https://news.v.daum.net/v/20190728165812603'
resp = requests.get(url)
print(resp)
print(resp.text)
# Out:
# <Response [200]>
# <!doctype html>
# <html lang="ko">
#  <head>
#   <meta charset="utf-8">
#   <meta http-equiv="X-UA-Compatible" content="IE=Edge">
#   <meta name="referrer" content="always">
#   <title>일론머스크 "테슬라에서 넷플릭스·유튜브 즐길 날 온다" | Daum 뉴스</title>
#   <link rel="shortcut icon" href="//m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico">
#   <style>
# @charset "utf-8";@font-face{font-family:'Nanum Myeongjo';font-style:normal;font-weight:400;src:url(//t1.daumcdn.net/media/news/news2016/font/NanumMyeongjo-Regular.eot);src:url(//t1.daumcdn.net/media/news/news2016/font/NanumMyeongjo-Regular.eot?#iefix) format('embedded-opentype'),url(//t1.daumcdn.net/media/news/news2016/font/NanumMyeongjo-Regular.woff2) format('woff2'),url(//t1.daumcdn.net/media/news/news2016/font/NanumMyeongjo-Regular.woff) format('woff'),url(//t1.daumcdn.net/media/news/news2016/font/NanumMyeongjo-Regular.ttf) format('truetype')}body,div,dl,dt,dd,ul,ol,li,h1,h2,h3,h4,h5,h6,pre,code,form,fieldset,legend,textarea,p,blockquote,th,td,input,select,textarea,button{margin:0;padding:0}fieldset,img{border:0 none}dl,ul,ol,menu,li{list-style:none}blockquote,q{quotes:none}blockquote:before,blockquote:after,q:before,q:after{content:'';content:none}input,select,textarea,button{vertical-align:middle}input::-ms-clear{display:none}button{border:0 none;background-color:transparent;cursor:pointer}button::-moz-focus-inner{padding:0;border:0}body{min-width:980px;background:#fff}body,th,td,input,select,textarea,button{font-size:14px;line-height:1.5;font-family:AppleSDGothicNeo-Regular,'Malgun Gothic','맑은 고딕',dotum,'돋움',sans-serif;color:#333;letter-spacing:-0.05em}a{color:#333;text-decoration:none}a:active,a:hover{text-decoration:underline}a:hover{color:#1e88e5}a:active{background-color:transparent}address,caption,cite,code,dfn,em,var{font-style:normal;font-weight:normal}.os_mac strong{font-weight:normal;font-family:AppleSDGothicNeo-Regular,sans-serif}html{overflow-y:scroll}#kakaoIndex{overflow:hidden;position:absolute;left:-9999px;width:0;height:1px;margin:0;padding:0}.ir_pm{display:block;overflow:hidden;font-size:0;line-height:0;text-indent:-9999px}.ir_wa{display:block;overflow:hidden;position:relative;z-index:-1;width:100%;height:100%}.screen_out{overflow:hidden;position:absolute;width:0;height:0;line-height:0;text-indent:-9999px}.show{display:block}.hide{display:none}.txt_newsview{display:block;overflow:hidden;font-size:0;line-height:0;background:url(//t1.daumcdn.net/media/common/newsview/txt_newsview_190618.png) 0 0 no-repeat;text-indent:-9999px;background-size:140px 750px}.ico_newsview{display:inline-block;overflow:hidden;font-size:0;line-height:0;background:url(//t1.daumcdn.net/media/common/newsview/ico_newsview_190327.png) 0 0 no-repeat;vertical-align:top;text-indent:-9999px;background-size:350px 350px}.ico_newsview2{background:url(//t1.daumcdn.net/media/common/newsview/ico_newsview2_180510.png) 0 0 no-repeat;background-size:50px 440px}.num_newsview{display:inline-block;overflow:hidden;font-size:0;line-height:0;background:url(//t1.daumcdn.net/media/common/newsview/num_newsview.png) 0 0 no-repeat;vertical-align:top;text-indent:-9999px;background-size:18px 600px}.link_cont,.link_thumb,.tit_g,.tit_thumb,.desc_thumb,.info_thumb{display:block}.link_thumb{position:relative}.link_thumb:before{position:absolute;top:0;left:0;right:0;bottom:0;z-index:10;border:1px solid #000;opacity:.05;content:''}.link_thumb:after{position:absolute;top:0;left:0;right:0;bottom:0;background:transparent;opacity:0;-webkit-transition:background .2s,opacity .2s;transition:background .2s,opacity .2s;content:''}.link_thumb:hover:after{background:#508dee;opacity:.45}.link_cont .wrap_thumb{display:block;position:relative}.link_cont .wrap_thumb:before{position:absolute;top:0;left:0;right:0;bottom:0;z-index:10;border:1px solid #000;opacity:.05;content:''}.link_cont .wrap_thumb:after{position:absolute;top:0;left:0;right:0;bottom:0;background:transparent;opacity:0;-webkit-transition:background .2s,opacity .2s;transition:background .2s,opacity .2s;content:''}.link_cont:hover .wrap_thumb:after{background:#508dee;opacity:.45}.cont_thumb{overflow:hidden}.inner_cont{display:table;width:100%;height:100%;table-layout:fixed}.inner_cont2{display:table-cell;vertical-align:middle}.thumb_g{vertical-align:top}.emph_g,.emph_g .link_txt{color:#396dbb}.emph_g2,.emph_g2 .link_txt{ ...
#
# .hcg_media_pc_cSub .btn_summary:focus{outline:none}
# .hcg_media_pc_kakaoHead .header_fixed .bar_progress{transition:width .4s ease-out;transform:rotateZ(0deg)}.hcg_media_pc_kakaoHead #kakaoGnb .inner_gnb{transform:rotateZ(0deg)}.hcg_media_pc_kakaoHead .news_type4 #mAside{position:relative;top:0}.hcg_media_pc_kakaoHead .news_type4 #mAside #floatingAside{transform:rotateZ(0deg)}.hcg_media_pc_kakaoHead .news_type4 #mAside .fixed{position:fixed;z-index:100}.hcg_media_pc_kakaoHead .news_type4 #mAside .fixed_bottom{position:relative !important;left:0 !important}.hcg_media_pc_kakaoHead .btn_empathy #empathy_pc .inner_empathy .btn_empathy{width:121px}.hcg_media_pc_kakaoHead .btn_empathy #empathy_pc .inner_empathy .img_empathy{background:none}.hcg_media_pc_kakaoHead .relate_series{display:none}.hcg_media_pc_kakaoHead .relate_series .link_prev img{margin-right:8px}.hcg_media_pc_kakaoHead .relate_series .link_next img{margin-left:8px}.hcg_media_pc_kakaoHead .chooad{margin-bottom:40px}.hcg_media_pc_kakaoHead .layer_summary .desc_summary .add_bottom{display:block;margin-bottom:20px}.hcg_media_pc_kakaoHead .gnb_comm .bar_gnb{display:inherit}.hcg_media_pc_kakaoHead .bar_gnb .inner_bar{width:0;transition:width .2s ease-in-out}.hcg_media_pc_kakaoHead #kakaoGnb .gnb_comm li:hover>a .bar_gnb .inner_bar{width:100%}
# .hcg_media_pc_mArticle .tit_subtxt1{margin:29px 15px;font-weight:normal;font-size:1.35em;line-height:1.36}.hcg_media_pc_mArticle .tit_subtxt1:first-child{margin-top:0}.hcg_media_pc_mArticle .tit_subtxt2{margin:31px 15px 10px;font-size:1.18em;line-height:1.36}.hcg_media_pc_mArticle .tit_subtxt2:first-child{margin-top:0}.hcg_media_pc_mArticle .quote_frm{overflow:hidden;position:relative;margin-bottom:30px;padding:25px 14px 0;font-weight:normal;font-size:1.24em;line-height:1.49;font-family:NanumMyeongjo,나눔명조,serif;text-align:center}.hcg_media_pc_mArticle .quote_frm:before{display:block;position:absolute;top:0;left:50%;width:15px;height:14px;margin-left:-7px;background:url(//m1.daumcdn.net/img-media/storyfunding/m320/img_quote.png) no-repeat;content:''}.hcg_media_pc_mArticle .talkquote_frm{overflow:hidden;position:relative;margin:29px 15px;padding-left:15px;line-height:1.6}.hcg_media_pc_mArticle .talkquote_frm:before{display:block;position:absolute;top:2px;left:0;width:2px;height:100%;background-color:#222;content:''}.hcg_media_pc_mArticle .talkquote_frm:after{display:block;position:absolute;bottom:0;left:0;width:2px;height:5px;background-color:#fff;content:''}.hcg_media_pc_mArticle .talkquote_frm .info_source{display:block;font-size:.76em;line-height:1.8;color:#808080}.hcg_media_pc_mArticle .talkquote_frm:first-child{margin-top:0}.hcg_media_pc_mArticle .talkquote_frm+.talkquote_frm{margin-top:31px}.hcg_media_pc_mArticle .talkquote_frm+div{margin-top:31px}.hcg_media_pc_mArticle [class*="tit_subtxt"]+.talkquote_frm{margin-top:10px}.hcg_media_pc_mArticle .figure_frm{display:block;margin:32px auto 30px auto;padding:0 15px;clear:left}.hcg_media_pc_mArticle .figure_frm .box_figure{display:block;padding:0 15px}.hcg_media_pc_mArticle .figure_frm .link_figure{display:block;position:relative}.hcg_media_pc_mArticle .slide_fig .link_figure:after{border:1px solid #000;opacity:.05;-ms-filter:"progid:DXImageTransform.Microsoft.Alpha(Opacity=5)"}.hcg_media_pc_mArticle .figure_frm .thumb_g{display:block;height:auto}.hcg_media_pc_mArticle .mglr_fig{padding:0}.hcg_media_pc_mArticle .mglr_fig .txt_caption{padding-right:15px;padding-left:15px}.hcg_media_pc_mArticle .origin_fig{display:table}.hcg_media_pc_mArticle .slide_fig{padding:0}.hcg_media_pc_mArticle .slide_fig .txt_caption{padding-right:15px;padding-left:15px}.hcg_media_pc_mArticle .slide_fig .inner_fig{overflow:hidden;position:relative;width:100%;height:auto}.hcg_media_pc_mArticle .slide_fig .btn_flick{position:absolute;top:0;bottom:47px;width:46px}.hcg_media_pc_mArticle .slide_fig .img_fig{display:inline-block;overflow:hidden;width:19px;height:33px;margin-top:28px;background:url(//m1.daumcdn.net/img-media/storyfunding/m320/img_fig.png) no-repeat;text-indent:-9999px}.hcg_media_pc_mArticle .slide_fig .btn_prev{left:0}.hcg_media_pc_mArticle .slide_fig .ico_prev{background-position:-1px -1px}.hcg_media_pc_mArticle .slide_fig .btn_next{right:0}.hcg_media_pc_mArticle .slide_fig .ico_next{background-position:-22px -1px}.hcg_media_pc_mArticle .slide_fig .page_count{position:absolute;right:14px;bottom:15px;min-height:15px;padding:1px 7px;border:1px solid rgba(0,0,0,0.1);border-radius:15px;font-size:.65em;line-height:1.1;font-family:HelveticaNeue,Helvetica,sans-serif;color:#666;background-color:rgba(255,255,255,0.5);letter-spacing:0;-webkit-box-sizing:border-box;-moz-box-sizing:border-box;box-sizing:border-box}.hcg_media_pc_mArticle .slide_fig .num_now{color:#333}.hcg_media_pc_mArticle .figure_frm:first-child{margin-top:0}.hcg_media_pc_mArticle .figure_frm+div{margin-top:40px}.hcg_media_pc_mArticle .figure_frm+.quote_frm{margin-top:30px}.hcg_media_pc_mArticle .video_frm{overflow:hidden;position:relative;width:100%;margin:32px 0 36px;padding-top:56.25%;clear:both}.hcg_media_pc_mArticle .video_frm .player_iframe{position:absolute;top:0;left:0;width:100%;height:100%}.hcg_media_pc_mArticle .video_frm+div{margin-top:40px}.hcg_media_pc_mArticle .video_frm:first-child{margin-top:0}.hcg_media_pc_mArticle .aud ...
# .hc_news_pc_cEtc_realtime_news_201904 .thumb_g{width:285px;height:160px}
# .hc_news_pc_cSub_printButton .btn_print:focus{border-color:#000;background-color:#000}.hc_news_pc_cSub_printButton .btn_print:focus .ico_newsview{background-position:-60px -40px}
# .hc_news_pc_cSub_shareButtons .social_comm_p{position:absolute;z-index:1000}.hc_news_pc_cSub_shareButtons .social_comm_p .img_social{display:block;overflow:hidden;font-size:0;background:url(//t1.daumcdn.net/daumtop_deco/images/common/social/img_social_180425.png) no-repeat 0 0;text-indent:-9999px}.hc_news_pc_cSub_shareButtons .social_comm_p .sns_comm_p{overflow:hidden;position:relative;border:1px solid #e2e2e2;font-size:12px;color:#222;background-color:#fff;letter-spacing:-0.025em}.hc_news_pc_cSub_shareButtons .social_comm_p .btn_close{position:absolute;top:7px;right:7px;width:24px;height:24px}.hc_news_pc_cSub_shareButtons .social_comm_p .ico_close{width:14px;height:14px;margin:5px;background-position:-150px 0}.hc_news_pc_cSub_shareButtons .social_comm_p .share_layer{position:relative;width:289px;min-height:253px}.hc_news_pc_cSub_shareButtons .social_comm_p .list_sns{overflow:hidden;margin:29px 15px 0}.hc_news_pc_cSub_shareButtons .social_comm_p .list_sns li{float:left;width:86px;height:86px}.hc_news_pc_cSub_shareButtons .social_comm_p .list_sns .link_sns{display:block;text-align:center;text-decoration:none}.hc_news_pc_cSub_shareButtons .social_comm_p .list_sns .link_sns .img_social{width:48px;height:48px;margin:0 auto}.hc_news_pc_cSub_shareButtons .social_comm_p .list_sns .tit_sns{display:block;margin-top:7px;font-weight:normal;line-height:16px}.hc_news_pc_cSub_shareButtons .social_comm_p .list_sns .ico_sns_ks{background-position:0 0}.hc_news_pc_cSub_shareButtons .social_comm_p .list_sns .ico_sns_fb{background-position:-50px 0}.hc_news_pc_cSub_shareButtons .social_comm_p .list_sns .ico_sns_tw{background-position:-100px 0}.hc_news_pc_cSub_shareButtons .social_comm_p .list_sns .ico_sns_cafe{background-position:0 -50px}.hc_news_pc_cSub_shareButtons .social_comm_p .list_sns .ico_sns_mail{background-position:-50px -50px}.hc_news_pc_cSub_shareButtons .social_comm_p .list_sns .ico_sns_kt{background-position:0 -100px}.hc_news_pc_cSub_shareButtons .social_comm_p .sns_copyurl{margin:1px 29px}.hc_news_pc_cSub_shareButtons .social_comm_p .sns_copyurl .link_copyurl{display:block;overflow:hidden;position:relative;height:25px;line-height:25px;border:1px solid #d0d0d0;background-color:#f8f8f8;text-decoration:none}.hc_news_pc_cSub_shareButtons .social_comm_p .sns_copyurl .txt_url{display:block;overflow:hidden;padding:0 60px 0 10px;color:#2695f8;white-space:nowrap;text-overflow:ellipsis}.hc_news_pc_cSub_shareButtons .social_comm_p .sns_copyurl .txt_copy{position:absolute;top:0;right:0;width:53px;height:25px;border-left:1px solid #d0d0d0;background-color:#fff;text-align:center}.hc_news_pc_cSub_shareButtons .social_comm_p .copyurl_layer{width:254px;height:78px;text-align:center}.hc_news_pc_cSub_shareButtons .social_comm_p .inner_copyurl{display:table;width:100%;height:100%}.hc_news_pc_cSub_shareButtons .social_comm_p .inner_copyurl .desc_copyurl{display:table-cell;padding:18px 0 17px;line-height:19px;vertical-align:middle}.hc_news_pc_cSub_shareButtons .social_comm_p .sns_copyurl_type2 .tf_url{display:block;width:210px;height:25px;padding:0 10px;border:0 none;color:#2695f8;background-color:transparent}.hc_news_pc_cSub_shareButtons .social_comm_p .sns_copyurl_type2 .desc_tip{padding:13px 0;line-height:18px;color:#888;text-align:center;letter-spacing:0}.hc_news_pc_cSub_shareButtons .social_comm_p{top:40px;right:-10px}.hc_news_pc_cSub_shareButtons .sns_comm_p .btn_close{display:none}@media only screen and (-webkit-min-device-pixel-ratio:1.5),only screen and (min-device-pixel-ratio:1.5),only screen and (min-resolution:144dpi),only screen and (min-resolution:1.5dppx){.hc_news_pc_cSub_shareButtons .social_comm_p .img_social{background-image:url(//t1.daumcdn.net/daumtop_deco/images/common/social/rtn/img_social_180425.png);background-size:170px 160px}}
# .hc_gallery_icon_on_image news_view figure .direct_view{overflow:hidden;position:absolute;left:50%;height:44px}
# .hc_news_pc_mAside_phototv .thumb_g{width:144px;height:140px}
#
# </style>
#   <!--[if IE ]>
# 	<script type="text/javascript" src="//t1.daumcdn.net/harmony_static/view_cloud/2019/07/01/183439/libIEPolyfills.js"></script>
# 	<![endif]-->
#   <!--[if lt IE 9]>
# 	<link type="text/css" rel="stylesheet" href="https://t1.daumcdn.net/harmony_static/view_cloud/2017/01/02/142101/media/ie8.css">
#     <link rel="stylesheet" type="text/css" href="https://t1.daumcdn.net/section/election/ticker.ie8.min.css">
# 	<![endif]-->
#   <meta property="twitter:card" content="summary_large_image">
#   <meta property="twitter:image" content="https://t1.daumcdn.net/news/201907/28/akn/20190728165813230vjsq.jpg">
#   <meta property="dg:uoc:pcUrl:" content="https://news.v.daum.net/v/20190728165812603">
#   <meta property="al:android:url" content="daumapps://web?url=https%3A%2F%2Fnews.v.daum.net%2Fv%2F20190728165812603">
#   <meta property="al:android:package" content="net.daum.android.daum">
#   <meta property="al:android:app_name" content="다음앱">
#   <meta property="al:ios:url" content="daumapps://web?url=https%3A%2F%2Fnews.v.daum.net%2Fv%2F20190728165812603">
#   <meta property="al:ios:app_store_id" content="365494029">
#   <meta property="al:ios:app_name" content="다음앱">
#   <meta property="twitter:app:url:googleplay" content="daumapps://web?url=https%3A%2F%2Fnews.v.daum.net%2Fv%2F20190728165812603">
#   <meta property="twitter:app:id:googleplay" content="net.daum.android.daum">
#   <meta property="twitter:app:name:googleplay" content="다음앱">
#   <meta property="twitter:app:country" content="KR">
#   <meta property="twitter:app:url:iphone" content="daumapps://web?url=https%3A%2F%2Fnews.v.daum.net%2Fv%2F20190728165812603">
#   <meta property="twitter:app:id:iphone" content="365494029">
#   <meta property="twitter:app:name:iphone" content="다음앱">
#   <meta property="twitter:app:url:ipad" content="daumapps://web?url=https%3A%2F%2Fnews.v.daum.net%2Fv%2F20190728165812603">
#   <meta property="twitter:app:id:ipad" content="365494029">
#   <meta property="twitter:app:name:ipad" content="다음앱">
#   <meta property="og:site_name" content="다음 뉴스">
#   <meta property="og:title" content="일론머스크 &quot;테슬라에서 넷플릭스·유튜브 즐길 날 온다&quot;">
#   <meta property="og:regDate" content="20190728165812">
#   <meta property="og:type" content="article">
#   <meta property="og:url" content="https://news.v.daum.net/v/20190728165812603">
#   <meta property="og:image" content="https://img1.daumcdn.net/thumb/S1200x630/?fname=https://t1.daumcdn.net/news/201907/28/akn/20190728165813230vjsq.jpg">
#   <meta property="og:image:width" content="1200">
#   <meta property="og:image:height" content="630">
#   <meta property="og:image" content="https://i1.daumcdn.net/img-media/mobile/meta/news.png?date=20170525">
#   <meta property="og:description" content="[아시아경제 이민우 기자] 일론 머스크 테슬라 최고경영자(CEO)가 자사 전기 자동차 모델에 넷플릭스와 유튜브 등 온라인동영상서비스(OTT)를 탑재할 것이라고 예고했다. 단순히 자율 주행 전기차가 단순히 주행을 위한 정보를 알려주는 것을 넘어 각종 영상 콘텐츠를 즐기는 공간으로도 확장하겠다는 전략으로 풀이된다.27일(현지시간) 더버지 등 주요 외신들에 따르">
#   <meta property="dg:uoc:svc" content="news">
#   <meta property="dg:uoc:uid" content="20190728165812603">
#   <meta property="dg:uoc:sc" content="article">
#   <meta property="dg:uoc:pcUrl" content="https://news.v.daum.net/v/20190728165812603">
#   <meta property="dg:uoc:mUrl" content="https://news.v.daum.net/v/20190728165812603?f=m">
#   <meta name="svcdomain" content="media.daum.net">
#   <!-- 다음탑 코코크러쉬 메타데이터 -->
#   <meta name="plink" content="https://news.v.daum.net/v/20190728165812603">
#   <meta property="article:txid" content="https://news.v.daum.net/v/20190728165812603">
#   <meta name="article:media_name" content="아시아경제">
#   <meta name="article:service_name" content="다음 뉴스">
#   <meta property="article:published_time" content="20190728165812">
#   <meta property="article:mobile_url" content="https://news.v.daum.net/v/20190728165812603?f=m">
#   <meta property="article:mobile_view_url" content="https://news.v.daum.net/v/20190728165812603?f=m">
#   <meta property="article:mobile_service_home" content="http://m.media.daum.net/">
#   <meta property="article:pc_url" content="https://news.v.daum.net/v/20190728165812603">
#   <meta property="article:pc_view_url" content="https://news.v.daum.net/v/20190728165812603">
#   <meta property="article:pc_service_home" content="http://media.daum.net/">
#   <meta property="article:talk_channel_view_url" content="https://v.kakao.com/v/20190728165812603">
#  </head>
#  <body>
#   <div id="kakaoIndex">
#    <a href="#kakaoBody">본문 바로가기</a>
#    <a href="#kakaoGnb">메뉴 바로가기</a>
#   </div>
#   <div id="kakaoWrap" class="newsview_media">
#    <!-- 2018-09-20 영어,인도네시아어 번역일 경우, lang_type1 클래스 추가 -->
#    <!-- 2018-09-20 중국어, 일본어 번역일 경우, lang_type2 클래스 추가 -->
#    <!-- 2018-09-11-v2  2018-09-20 베트남어 번역일 때 lang_type3 클래스 추가 -->
#    <div id="kakaoHead" role="banner" class="#gnb #default hcg_media_pc_kakaoHead">
#     <div class="head_media">
#      <h1> <a href="https://www.daum.net/" class="link_daum"> <img src="//t1.daumcdn.net/media/news/news2016/retina/logo_daum.jpg" width="45" height="19" class="thumb_g" alt="Daum"> </a> <a href="https://media.daum.net/" id="kakaoServiceLogo"><span class="ir_wa">뉴스</span></a> </h1>
#      <strong class="screen_out">관련서비스</strong>
#      <ul id="kakaoRelServices">
#       <li><a href="https://media.daum.net/entertain/" class="link_services link_services1"><span class="ir_wa">연예</span></a></li>
#       <li><a href="https://sports.media.daum.net/sports/" class="link_services link_services2"><span class="ir_wa">스포츠</span></a></li>
#      </ul>
#      <h2 class="screen_out">검색</h2>
#      <div class="search_news" id="search_news">
#       <form id="kakaoSearch" name="kakaoSearch" action="https://search.daum.net/search" method="get">
#        <fieldset class="fld_inside">
#         <legend class="screen_out">검색어 입력폼</legend>
#         <div class="box_searchbar">
#          <label for="qVal" class="lab_search">통합검색</label>
#          <input type="hidden" name="nil_profile" value="search">
#          <input type="hidden" name="nil_src" value="media">
#          <input type="hidden" name="DA" value="23A">
#          <input type="hidden" name="rtmaxcoll" value="NNS">
#          <input type="text" class="tf_keyword" id="qVal" name="q" value="" title="검색어 입력" autocomplete="off" spellcheck="false">
#          <button id="kakaoBtnSearch" class="btn_search" type="submit"><span class="ir_wa">검색</span></button>
#         </div>
#        </fieldset>
#        <div id="wrap_suggestBox" class="wrap_suggestBox">
#         <div id="suggestBox" class="suggestBox box_sub">
#          <div class="baseBox bg" style="display: none"></div>
#         </div>
#        </div>
#       </form>
#      </div>
#     </div>
#     <div id="kakaoGnb" role="navigation">
#      <div class="inner_gnb">
#       <h2 class="screen_out">뉴스 메인메뉴</h2>
#       <ul class="gnb_comm" data-category="digital">
#        <li class="home"><a href="https://media.daum.net/" class="link_gnb link_gnb1"><span class="ir_wa">홈</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
#        <li class="society"><a href="https://media.daum.net/society/" class="link_gnb link_gnb2"><span class="ir_wa">사회</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
#        <!-- 현재페이지에 on클래스 추가  -->
#        <li class="politics"><a href="https://media.daum.net/politics/" class="link_gnb link_gnb3"><span class="ir_wa">정치</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
#        <li class="economic"><a href="https://media.daum.net/economic/" class="link_gnb link_gnb4"><span class="ir_wa">경제</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
#        <li class="foreign"><a href="https://media.daum.net/foreign/" class="link_gnb link_gnb5"><span class="ir_wa">국제</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
#        <li class="culture"><a href="https://media.daum.net/culture/" class="link_gnb link_gnb6"><span class="ir_wa">문화</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
#        <li class="digital"><a href="https://media.daum.net/digital/" class="link_gnb link_gnb7"><span class="ir_wa">IT</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
#        <li class="popular"><a href="https://media.daum.net/ranking/popular/" class="link_gnb link_gnb8"><span class="ir_wa">랭킹</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
#        <li class="series"><a href="https://media.daum.net/series/" class="link_gnb link_gnb9"><span class="ir_wa">연재</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
#        <li class="photo"><a href="https://media.daum.net/photo/" class="link_gnb link_gnb10"><span class="ir_wa">포토</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
#        <li class="tv"><a href="https://media.daum.net/tv/" class="link_gnb link_gnb11"><span class="ir_wa">TV</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
#       </ul>
#       <div class="gnb_etc">
#        <ul class="gnb_with">
#         <li><a href="https://media.daum.net/1boon/" class="link_gnb link_gnb1"><span class="ir_wa">1boon</span></a></li>
#         <li><a href="//gallery.v.daum.net/p/home" class="link_gnb link_gnb2"><span class="ir_wa">사진전</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
#        </ul>
#        <div class="gnb_weather hc_news_pc_kakaoHead_gnbWeather">
#         <strong class="screen_out">날씨 정보</strong>
#         <div id="gnb_weather">
#          <ul class="list_weather" data-nightyn="Y">
#           <!-- 69px씩 이동합니다 / 밤일 경우, type_night 클래스 추가 -->
#           <li> <a href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=서울%20날씨" class="link_cont"> <span class="ico_weather ico_weather4">서울</span> <span class="txt_weather">서울 <span class="num_heat">5</span> <span class="txt_heat">℃</span> </span> </a> </li>
#           <li> <a href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=수원%20날씨" class="link_cont"> <span class="ico_weather ico_weather3">수원</span> <span class="txt_weather">수원 <span class="num_heat">4</span> <span class="txt_heat">℃</span> </span> </a> </li>
#           <li> <a href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=인천%20날씨" class="link_cont"> <span class="ico_weather ico_weather4">인천</span> <span class="txt_weather">인천 <span class="num_heat">2</span> <span class="txt_heat">℃</span> </span> </a> </li>
#           <li> <a href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=대구%20날씨" class="link_cont"> <span class="ico_weather ico_weather3">대구</span> <span class="txt_weather">대구 <span class="num_heat">8</span> <span class="txt_heat">℃</span> </span> </a> </li>
#           <li> <a href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=대전%20날씨" class="link_cont"> <span class="ico_weather ico_weather3">대전</span> <span class="txt_weather">대전 <span class="num_heat">6</span> <span class="txt_heat">℃</span> </span> </a> </li>
#           <li> <a href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=광주%20날씨" class="link_cont"> <span class="ico_weather ico_weather3">광주</span> <span class="txt_weather">광주 <span class="num_heat">7</span> <span class="txt_heat">℃</span> </span> </a> </li>
#           <li> <a href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=부산%20날씨" class="link_cont"> <span class="ico_weather ico_weather2">부산</span> <span class="txt_weather">부산 <span class="num_heat">8</span> <span class="txt_heat">℃</span> </span> </a> </li>
#           <li> <a href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=울산%20날씨" class="link_cont"> <span class="ico_weather ico_weather2">울산</span> <span class="txt_weather">울산 <span class="num_heat">8</span> <span class="txt_heat">℃</span> </span> </a> </li>
#           <li> <a href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=울릉/독도%20날씨" class="link_cont"> <span class="ico_weather ico_weather4">울릉/독도</span> <span class="txt_weather">울릉/독도 <span class="num_heat">6</span> <span class="txt_heat">℃</span> </span> </a> </li>
#           <li> <a href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=춘천%20날씨" class="link_cont"> <span class="ico_weather ico_weather2">춘천</span> <span class="txt_weather">춘천 <span class="num_heat">3</span> <span class="txt_heat">℃</span> </span> </a> </li>
#           <li> <a href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=강릉%20날씨" class="link_cont"> <span class="ico_weather ico_weather2">강릉</span> <span class="txt_weather">강릉 <span class="num_heat">7</span> <span class="txt_heat">℃</span> </span> </a> </li>
#           <li> <a href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=백령%20날씨" class="link_cont"> <span class="ico_weather ico_weather4">백령</span> <span class="txt_weather">백령 <span class="num_heat">4</span> <span class="txt_heat">℃</span> </span> </a> </li>
#           <li> <a href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=청주%20날씨" class="link_cont"> <span class="ico_weather ico_weather3">청주</span> <span class="txt_weather">청주 <span class="num_heat">1</span> <span class="txt_heat">℃</span> </span> </a> </li>
#           <li> <a href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=전주%20날씨" class="link_cont"> <span class="ico_weather ico_weather3">전주</span> <span class="txt_weather">전주 <span class="num_heat">7</span> <span class="txt_heat">℃</span> </span> </a> </li>
#           <li> <a href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=목포%20날씨" class="link_cont"> <span class="ico_weather ico_weather4">목포</span> <span class="txt_weather">목포 <span class="num_heat">6</span> <span class="txt_heat">℃</span> </span> </a> </li>
#           <li> <a href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=여수%20날씨" class="link_cont"> <span class="ico_weather ico_weather2">여수</span> <span class="txt_weather">여수 <span class="num_heat">8</span> <span class="txt_heat">℃</span> </span> </a> </li>
#           <li> <a href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=제주%20날씨" class="link_cont"> <span class="ico_weather ico_weather3">제주</span> <span class="txt_weather">제주 <span class="num_heat">11</span> <span class="txt_heat">℃</span> </span> </a> </li>
#           <li> <a href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=안동%20날씨" class="link_cont"> <span class="ico_weather ico_weather1">안동</span> <span class="txt_weather">안동 <span class="num_heat">5</span> <span class="txt_heat">℃</span> </span> </a> </li>
#           <li> <a href="http://search.daum.net/search?nil_suggest=btn&amp;w=tot&amp;DA=SBC&amp;q=창원%20날씨" class="link_cont"> <span class="ico_weather ico_weather3">창원</span> <span class="txt_weather">창원 <span class="num_heat">5</span> <span class="txt_heat">℃</span> </span> </a> </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div id="barProgress" class="bar_progress"></div>
#    </div>
#    <hr class="hide hcg_media_pc_kakaoHead">
#    <div id="kakaoContent" class="cont_view" role="main">
#     <h2 id="kakaoBody" class="screen_out">IT</h2>
#     <div id="cSub" class="hcg_media_pc_cSub">
#      <div class="head_view">
#       <em class="info_cp"> <a href="https://www.asiae.co.kr" class="link_cp #body #cplogo" target="_blank"> <img src="https://t1.daumcdn.net/media/news/news2016/cp/cp_akn.gif" class="thumb_g" alt="아시아경제"> </a> </em>
#       <h3 class="tit_view" data-translation>일론머스크 "테슬라에서 넷플릭스·유튜브 즐길 날 온다"</h3>
#       <span class="info_view"> <span class="txt_info">이민우</span> <span class="txt_info">입력 2019.07.28. 16:58</span> <button id="alexCounter" class="emph_g2 link_cmt">댓글 <span class="alex-count-area">0</span>개</button> </span>
#       <div class="util_view">
#        <!-- 2018-08-31-v2 버튼 순서 변경 / 자동요약 - TTS - 번역 - 공유 - 글씨크기 - 인쇄 순 -->
#        <!-- 자동요약 -->
#        <div class="btn_util util_summary">
#         <!-- btn_summary 클릭시, layer_open 클래스 추가 -->
#         <button type="button" class="btn_summary #btn_summary" aria-expanded="false"><span class="ico_newsview">자동요약</span></button>
#         <div class="wrap_setlayer">
#          <div class="layer_util layer_summary">
#           <p>일론 머스크 테슬라 최고경영자(CEO)가 자사 전기 자동차 모델에 넷플릭스와 유튜브 등 온라인동영상서비스(OTT)를 탑재할 것이라고 예고했다.</p>
#           <p>단순히 자율 주행 전기차가 단순히 주행을 위한 정보를 알려주는 것을 넘어 각종 영상 콘텐츠를 즐기는 공간으로도 확장하겠다는 전략으로 풀이된다.</p>
#           <p>테슬라 측은 규제당국이 자율주행에 대해 완전히 승인하면 차량이 움직일 때에도 승객이 동영상을 즐길 수 있을 것이라고 설명했다.</p>
#           <span class="info_summary"><span class="ico_newsview"></span>기사 제목과 주요 문장을 기반으로 자동요약한 결과입니다. 전체 맥락을 이해하기 위해서는 본문 보기를 권장합니다.</span>
#          </div>
#         </div>
#        </div>
#        <!-- TTS -->
#        <div class="btn_util tts_btn hc_news_pc_cSub_tts">
#         <button type="button" class="btn_set btn_tts" aria-expanded="false"> <span class="ico_newsview ico_speak">음성 기사 듣기</span> </button>
#         <div class="wrap_setlayer">
#          <div class="layer_util layer_set layer_tts">
#           <strong class="screen_out">음성 기사 옵션 조절 레이어</strong>
#           <ul class="list_set list_tts">
#            <li> <input type="radio" id="ttsGenderMale" name="ttsGender" class="screen_out" value="Male"> <label class="lab_set" for="ttsGenderMale"><span class="ico_newsview"></span>남성</label> </li>
#            <li> <input type="radio" id="ttsGenderFemale" name="ttsGender" class="screen_out" value="Female"> <label class="lab_set" for="ttsGenderFemale"><span class="ico_newsview"></span>여성</label> </li>
#           </ul>
#           <ul class="list_set list_tts list_ttsspeed">
#            <li> <input type="radio" id="ttsSpeedSlow" name="ttsSpeed" class="screen_out" value="slow"> <label class="lab_set" for="ttsSpeedSlow"><span class="ico_newsview"></span>느림</label> </li>
#            <li> <input type="radio" id="ttsSpeedNormal" name="ttsSpeed" class="screen_out" value="normal"> <label class="lab_set" for="ttsSpeedNormal"><span class="ico_newsview"></span>보통</label> </li>
#            <li> <input type="radio" id="ttsSpeedFast" name="ttsSpeed" class="screen_out" value="fast"> <label class="lab_set" for="ttsSpeedFast"><span class="ico_newsview"></span>빠름</label> </li>
#           </ul>
#          </div>
#         </div>
#         <audio style="display:none" preload="none" id="ttsPlayer"></audio>
#        </div>
#        <!-- 번역 -->
#        <div class="btn_util translate_btn hc_news_pc_cSub_translateButtons">
#         <!-- 활성화시 aria-expanded="true" / 비활성화시 aria-expanded="false" 추가 -->
#         <button type="button" class="btn_set btn_translate #util #translate #set" aria-expanded="false"><span class="ico_newsview">번역 설정</span></button>
#         <div class="wrap_translatelayer">
#          <div class="layer_util layer_translate">
#           <strong class="tit_translate">번역<span class="ico_newsview">beta</span>
#            <!-- 2018-09-04 추가--></strong>
#           <p class="desc_translate txt_newsview">Translated by <a href="https://kakao.ai/" target="_blank" class="link_kakaoi #util #translate #kakaoi_link">kakao i</a></p>
#           <strong class="screen_out">번역할 언어 선택</strong>
#           <ul class="list_lang">
#            <li> <button class="btn_lang btn_en #util #translate #lang_en" name="en"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">English</strong> </button> </li>
#            <li> <button type="button" class="btn_lang btn_ch #util #translate #lang_cn" name="cn"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">简体中文</strong> </button> </li>
#            <li> <button type="button" class="btn_lang btn_jp #util #translate #lang_jp" name="jp"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">日本語</strong> </button> </li>
#            <li> <button type="button" class="btn_lang btn_ind #util #translate #lang_id" name="id"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">Bahasa Indonesia</strong> </button> </li>
#            <li> <button type="button" class="btn_lang btn_viet #util #translate #lang_vi" name="vi"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">tiếng Việt</strong> </button> </li>
#            <li> <button type="button" class="btn_lang btn_ko #util #translate #lang_kr" name="kr"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">한국어</strong> </button> </li>
#           </ul>
#          </div>
#         </div>
#        </div>
#        <div style="display:none;" class="hc_translator"></div>
#        <!-- 공유 -->
#        <div class="btn_util share_btn hc_news_pc_cSub_shareButtons">
#         <button id="rSocialShareButton" class="btn_set btn_share" aria-expanded="false"> <span class="ico_newsview">공유</span> </button>
#         <div id="rSocialShareLayerContainer"></div>
#        </div>
#        <!-- 글씨크기 -->
#        <div class="font_btn btn_util hc_news_pc_cSub_fontSizeController">
#         <button type="button" class="btn_set btn_font" aria-expanded="false"> <span class="ico_newsview ico_font">글씨크기 조절하기</span> </button>
#         <div class="wrap_setlayer">
#          <div class="layer_util layer_set layer_font">
#           <strong class="screen_out">글자 크기 조절 레이어</strong>
#           <ul class="list_set list_font">
#            <li> <input type="radio" id="inpFont17" name="inpFont" class="screen_out" value="17"> <label class="lab_set lab_size0" for="inpFont17"> <span class="ico_newsview"></span> <span aria-hidden="true">가나다라마바사</span> <span class="screen_out">매우 작은 폰트</span> </label> </li>
#            <li> <input type="radio" id="inpFont18" name="inpFont" class="screen_out" value="18"> <label class="lab_set lab_size1" for="inpFont18"> <span class="ico_newsview"></span> <span aria-hidden="true">가나다라마바사</span> <span class="screen_out">작은 폰트</span> </label> </li>
#            <li> <input type="radio" id="inpFont19" name="inpFont" class="screen_out" value="19"> <label class="lab_set lab_size2" for="inpFont19"> <span class="ico_newsview"></span> <span aria-hidden="true">가나다라마바사</span> <span class="screen_out">보통 폰트</span> </label> </li>
#            <li> <input type="radio" id="inpFont20" name="inpFont" class="screen_out" value="20"> <label class="lab_set lab_size3" for="inpFont20"> <span class="ico_newsview"></span> <span aria-hidden="true">가나다라마바사</span> <span class="screen_out">큰 폰트</span> </label> </li>
#            <li> <input type="radio" id="inpFont21" name="inpFont" class="screen_out" value="21"> <label class="lab_set lab_size4" for="inpFont21"> <span class="ico_newsview"></span> <span aria-hidden="true">가나다라마바사</span> <span class="screen_out">매우 큰 폰트</span> </label> </li>
#           </ul>
#          </div>
#         </div>
#         <!-- // font 팝업 레이어 -->
#        </div>
#        <!-- 인쇄 -->
#        <div class="btn_util hc_news_pc_cSub_printButton">
#         <button type="button" class="btn_print"> <span class="ico_newsview">인쇄하기 새창열림</span> </button>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div id="cMain">
#      <div id="mArticle" class="hcg_media_pc_mArticle">
#       <!-- 바꿔치기 -->
#       <!-- 언론중재법 -->
#       <!-- 번역 안내 -->
#       <div id="translateNotice" class="status_view" style="display:none;">
#        <span class="notice_lang notice_lang_en" style="display:none;">The copyright belongs to the original writer of the content, and there may be errors in machine translation results.</span>
#        <span class="notice_lang notice_lang_cn" style="display:none;">版权归内容原作者所有。机器翻译结果可能存在错误。</span>
#        <span class="notice_lang notice_lang_jp" style="display:none;">原文の著作権は原著著作者にあり、機械翻訳の結果にエラーが含まれることがあります。</span>
#        <span class="notice_lang notice_lang_id" style="display:none;">Hak cipta milik penulis asli dari konten, dan mungkin ditemukan kesalahan dalam hasil terjemahan mesin.</span>
#        <span class="notice_lang notice_lang_vi" style="display:none;">Bản quyền thuộc về tác giả gốc của nội dung và có thể có lỗi trong kết quả dịch bằng máy.</span>
#       </div>
#       <div class="news_view" style="font-size:17px">
#        <strong class="summary_view" data-translation>"주행 중에도 넷플릭스·유튜브 감상 가능할 것"<br>자율주행 아직까지 안전 우려 남아..실현 시기는 미지수</strong>
#        <div id="harmonyContainer" class="article_view" data-translation-body>
#         <section dmcf-sid="NkBWHdyrlY">
#          <figure class="figure_frm origin_fig" dmcf-pid="N7s2biXYTL" dmcf-ptype="figure">
#           <p class="link_figure"><img alt="일론 머스크 테슬라 최고경영자(CEO) [이미지출처=로이터연합뉴스]" class="thumb_g_article" dmcf-mid="NBMY3ZZhN4" dmcf-mtype="image" height="366" src="https://t1.daumcdn.net/news/201907/28/akn/20190728165813230vjsq.jpg" width="550"></p>
#           <figcaption class="txt_caption default_figure">
#            일론 머스크 테슬라 최고경영자(CEO) [이미지출처=로이터연합뉴스]
#           </figcaption>
#          </figure>
#          <div dmcf-pid="NU9K9rfDgA" dmcf-ptype="general">
#           <p>[아시아경제 이민우 기자] 일론 머스크 테슬라 최고경영자(CEO)가 자사 전기 자동차 모델에 넷플릭스와 유튜브 등 온라인동영상서비스(OTT)를 탑재할 것이라고 예고했다. 단순히 자율 주행 전기차가 단순히 주행을 위한 정보를 알려주는 것을 넘어 각종 영상 콘텐츠를 즐기는 공간으로도 확장하겠다는 전략으로 풀이된다.</p>
#           <br>
#           <p>27일(현지시간) 더버지 등 주요 외신들에 따르면 머스크 CEO는 자신의 트위터를 통해 이 같은 계획을 밝혔다. 그는 "자동차가 정차했을 때 넷플릭스와 유튜브를 감상할 수 있는 기능이 조만간 추가될 것"이라며 "편안한 좌석과 서라운드 사운드 오디오를 통해 영화관과 같은 느낌을 받을 수 있을 것"이라고 강조했다.</p>
#          </div>
#          <figure class="figure_frm origin_fig" dmcf-pid="NlqQhf4JmF" dmcf-ptype="figure">
#           <p class="link_figure"><img alt="(출처=일론 머스크 트위터 계정 캡쳐)" class="thumb_g_article" dmcf-mid="NRhnb5SRpx" dmcf-mtype="image" height="352" src="https://t1.daumcdn.net/news/201907/28/akn/20190728165813670hwxf.png" width="550"></p>
#           <figcaption class="txt_caption default_figure">
#            (출처=일론 머스크 트위터 계정 캡쳐)
#           </figcaption>
#          </figure>
#          <div dmcf-pid="NpkG4d9A6j" dmcf-ptype="general">
#           <p>테슬라가 이처럼 콘텐츠 방면으로 확장하려 든 것은 이번이 처음이 아니다. 지난달 세계 최대 게임쇼 E3에서는 이미 운전자가 '폴아웃 쉘터'라는 게임을 할 수 있을 것이라고 발표한 바 있다. 이후에도 최근 게임업체 아타리사(社)의 자동차 경주 게임 ‘폴포지션’, 슈팅게임 ‘템페스트’, ‘미사일커맨드’ 등 고전 게임을 제공하기도 했다. 운전대로 게임을 조작하는 방식으로, 차가 주차돼 있을 경우에만 즐길 수 있다.</p>
#           <br>
#           <p>이번 영상 콘텐츠는 주행 중에도 감상할 수 있도록 하는 방안을 고려하고 있다. 테슬라 측은 규제당국이 자율주행에 대해 완전히 승인하면 차량이 움직일 때에도 승객이 동영상을 즐길 수 있을 것이라고 설명했다.</p>
#           <br>
#           <p>하지만 아직까지 자율주행차의 안전에 대한 우려는 완전히 걷혀지지 않은 상황이다. 지난 2017년 차량공유 서비스 우버의 자율주행 시범차량이 보행자와 충돌한 사고가 발생한 바 있다. 게다가 당시 시험 운전자는 디즈니의 동영상 스트리밍 서비스인 '훌루'를 이용하고 있던 것으로 밝혀졌다.</p>
#          </div>
#          <p dmcf-pid="NUOWg8Qxyd" dmcf-ptype="general">이민우 기자 letzwin@asiae.co.kr</p>
#         </section>
#        </div>
#       </div>
#       <div class="foot_view">
#        <div class="wrap_brunch hc_news_pc_mArticle_brunchAuthor" style="display:none;">
#        </div>
#        <div class="relate_tag hc_news_pc_mArticle_relatedTags">
#         <strong class="screen_out">관련 태그</strong>
#        </div>
#        <div class="relate_series hc_news_pc_mArticle_series" style="display:none;">
#         <strong class="tit_series"><em class="tag_series">연재</em><span class="title_series"></span></strong>
#         <!-- MCCP-856 연재 영역 수정 -->
#         <ul class="list_series">
#         </ul>
#         <!-- //MCCP-856 연재 영역 수정 -->
#         <a href="#none" class="link_more #body #series_more">더보기</a>
#        </div>
#        <div class="copyright_view">
#         <span class="txt_copyright">ⓒ세계를 보는 창 경제를 보는 눈, 아시아경제(www.asiae.co.kr)</span>
#         <div class="btn_empathy hc_news_pc_mArticle_empathyButton">
#          <link rel="stylesheet" type="text/css" href="//m1.daumcdn.net/svc/original/U03/cssjs/uoclike/common/uoclike.min-20150408-2.css">
#          <div id="likeButton" class="btn_empathy_pc">
#          </div>
#         </div>
#        </div>
#        <!-- 언론사 관련기사(주요뉴스) -->
#        <div class="cp_view">
#         <strong class="tit_cp">아시아경제 주요 뉴스<span class="info_cp">해당 언론사로 연결됩니다.</span></strong>
#         <ul class="list_relate">
#          <li><a href="https://www.asiae.co.kr/article/2020010317520122501&amp;access=daum" class="link_txt #body #outmedia #related_list" target="_blank" data-type="rss">진중권에 한방 날린 정봉주 "공부 안해, 대학교때…"</a></li>
#          <li><a href="https://www.asiae.co.kr/article/2020010309431046369&amp;access=daum" class="link_txt #body #outmedia #related_list" target="_blank" data-type="rss">'한국인? 중국인?'…교황 분노케 한 신도 국적은</a></li>
#          <li><a href="https://www.asiae.co.kr/article/2020010409122857000&amp;access=daum" class="link_txt #body #outmedia #related_list" target="_blank" data-type="rss">스타의 15세 연하 아내 "평생 배변주머니" 고백 왜?</a></li>
#          <li><a href="https://www.asiae.co.kr/article/2020010407502507078&amp;access=daum" class="link_txt #body #outmedia #related_list" target="_blank" data-type="rss">"유시민 거짓" 과거 한솥밥 먹던 이부영 작심 비판</a></li>
#          <li><a href="https://www.asiae.co.kr/article/2020010514073718719&amp;access=daum" class="link_txt #body #outmedia #related_list" target="_blank" data-type="rss">진중권 "윤석열 수족부터…친문, 檢 길들이기 시작"</a></li>
#          <li><a href="https://www.asiae.co.kr/article/2020010219433365771&amp;access=daum" class="link_txt #body #outmedia #related_list" target="_blank" data-type="rss">친부에게 성폭행당한 13세 소녀, 출산 직후 사망</a></li>
#          <li><a href="https://www.asiae.co.kr/article/2020010301551657641&amp;access=daum" class="link_txt #body #outmedia #related_list" target="_blank" data-type="rss">오징어잡이 7시간 함께 했는데 고작…30년래 '최악'</a></li>
#          <li><a href="https://www.asiae.co.kr/article/2020010217095746546&amp;access=daum" class="link_txt #body #outmedia #related_list" target="_blank" data-type="rss">모친 살해 혐의로 체포된 유명영화 여배우</a></li>
#          <li><a href="https://www.asiae.co.kr/article/2020010314032792116&amp;access=daum" class="link_txt #body #outmedia #related_list" target="_blank" data-type="rss">사고 현장서 목격된 트레이닝복 男…알고보니 연예인</a></li>
#          <li><a href="https://www.asiae.co.kr/article/2020010315460259842&amp;access=daum" class="link_txt #body #outmedia #related_list" target="_blank" data-type="rss">신호 대기 중 차량 창문 열고 음란행위한 50대</a></li>
#         </ul>
#        </div>
#        <div id="alex-scroll-area"></div>
#        <ins class="daum_ddn_area recomm_ad hc_news_pc_mArticle_recommend_ad" style="display:block; width: 658px; text-decoration: none; min-width: 658px; min-height: 90px; height: 90px;" data-ad-unit="DAN-1jezdswwiit7q" data-ad-width="658" data-ad-height="90"></ins>
#        <div class="cmt_news cmt_view">
#         <div id="alex-area" class="alex-area" data-post-id="@20190728165812603" data-client-id="26BXAvKny5WF5Z09lr5k77Y8" data-base-url="//comment.daum.net" data-max-length="300" data-is-mobile="false" data-use-reply="true" data-use-official="true" data-use-my="true" data-use-social-share="true" data-sort="R" data-use-emoticon="true" data-use-attachment="false" data-kakao-appkey="9076ba452fea1a434141d6b6a2c11a3c" data-show-mask-alert="true" data-initial-limit="3" data-page-limit="10" data-use-live-comment-mode="notify">
#         </div>
#        </div>
#       </div>
#      </div>
#      <div id="mAside" class="hcg_media_pc_mAside">
#       <div style="position:relative" class="hc_news_pc_cSub_bnr_130">
#        <div class="bnr_130">
#         <ins id="RIGHT_SPACE_BANNER" name="RIGHT_SPACE_BANNER" class="daum_ddn_area" data-ad-unit="05d90" data-ad-type="P" data-ad-width="130" data-ad-height="250"></ins>
#        </div>
#       </div>
#       <!-- //130 배너 -->
#       <ins style="display:block;width:250px;height:250px;" class="daum_ddn_area aside_g aside_ad hc_news_pc_mAside_asideTopAd" data-ad-unit="05d24" data-ad-type="D" data-ad-width="250" data-ad-height="250"></ins>
#       <div class="hc_news_pc_mAside_popular_news">
#        <div class="aside_g aside_popular" data-react-checksum="728820392" data-reactid=".twq2cleifb">
#         <h3 class="txt_newsview" data-reactid=".twq2cleifb.0">많이본 뉴스</h3>
#         <ul class="tab_aside tab_media" data-reactid=".twq2cleifb.1">
#          <li class="on" data-reactid=".twq2cleifb.1.0"><a class="link_tab link_tab2 #right #popular_tab #news" data-reactid=".twq2cleifb.1.0.0" href="#none">뉴스</a>
#           <div class="cont_aside" data-reactid=".twq2cleifb.1.0.1">
#            <strong class="screen_out" data-reactid=".twq2cleifb.1.0.1.0">뉴스</strong>
#            <ol class="list_ranking #right #popular_news #news_list" data-reactid=".twq2cleifb.1.0.1.1">
#             <li data-reactid=".twq2cleifb.1.0.1.1.$news1"><em class="num_newsview num1" data-reactid=".twq2cleifb.1.0.1.1.$news1.0"><span data-reactid=".twq2cleifb.1.0.1.1.$news1.0.0">1</span><span data-reactid=".twq2cleifb.1.0.1.1.$news1.0.1">위</span></em><strong class="tit_g" data-reactid=".twq2cleifb.1.0.1.1.$news1.1"><a class="link_txt @1" data-reactid=".twq2cleifb.1.0.1.1.$news1.1.0" href="https://v.daum.net/v/20200105161518579">檢, 패스트트랙 약식기소 한국당 의원 2명에 '당선무효형' 구형</a></strong></li>
#             <li data-reactid=".twq2cleifb.1.0.1.1.$news2"><em class="num_newsview num2" data-reactid=".twq2cleifb.1.0.1.1.$news2.0"><span data-reactid=".twq2cleifb.1.0.1.1.$news2.0.0">2</span><span data-reactid=".twq2cleifb.1.0.1.1.$news2.0.1">위</span></em><strong class="tit_g" data-reactid=".twq2cleifb.1.0.1.1.$news2.1"><a class="link_txt @2" data-reactid=".twq2cleifb.1.0.1.1.$news2.1.0" href="https://v.daum.net/v/20200105150803923">'새보수당' 출범.. 30년 만에 청바지 입은 유승민 "8석을 80석 만들겠다"</a></strong></li>
#             <li data-reactid=".twq2cleifb.1.0.1.1.$news3"><em class="num_newsview num3" data-reactid=".twq2cleifb.1.0.1.1.$news3.0"><span data-reactid=".twq2cleifb.1.0.1.1.$news3.0.0">3</span><span data-reactid=".twq2cleifb.1.0.1.1.$news3.0.1">위</span></em><strong class="tit_g" data-reactid=".twq2cleifb.1.0.1.1.$news3.1"><a class="link_txt @3" data-reactid=".twq2cleifb.1.0.1.1.$news3.1.0" href="https://v.daum.net/v/20200105155702052">[레이더P] 정당투표 득표율, 정의당 12% 비례한국당 3.6%</a></strong></li>
# ...
#
# (0,eval("(function(elements){\nvar TAB_HEADS \x3d $(\x22#search_rank_tab_heads \x3e li \x3e a\x22).each(function() {\n  this.tabId \x3d this.hash.substring(1);\n  this.tab \x3d $(\x27#\x27 +  this.tabId);\n  $(this).on(\x27mouseover focus\x27, function (ev) {\n    var selection \x3d this.tabId;\n\n    ev.originalEvent.preventDefault();\n    TAB_HEADS.each(function () {\n      if (this.tabId \x3d\x3d\x3d selection) {\n        $(this).parent().addClass(\x27on\x27);\n        this.tab.css(\x27display\x27, \x27block\x27);\n      } else {\n        $(this).parent().removeClass(\x27on\x27);\n        this.tab.css(\x27display\x27, \x27none\x27);\n      }\n    });\n  });\n  $(this).on(\x27click\x27, function (ev) {\n    var e \x3d ev.originalEvent || ev;\n    e.preventDefault();\n  });\n});\n})(document.querySelectorAll(\x22.hc_news_pc_mAside_realtimeSearch\x22));"));
#
# (0,eval("(function(elements){\n\n})(document.querySelectorAll(\x22.hcg_common_new_tiara\x22));"));
#
# (0,eval("(function(elements){\n\n})(document.querySelectorAll(\x22.hcg_media_pc_cEtc\x22));"));
#
# (0,eval("(function(elements){\n(function($){\n\t\x27use strict\x27;\n\tvar summaryButton \x3d $(\x27.btn_summary\x27);\n\tvar summaryLayer \x3d $(\x27.util_summary\x27);\n\tvar shareButtonsLayer \x3d $(\x27#shareButtons\x27);\n\tvar summaryLayerStatus \x3d false;\n\n\tsummaryButton.on(\x27click\x27, function (ev) {\n\t\tsummaryLayerStatus \x3d !summaryLayerStatus;\n\n\t\tif (summaryLayerStatus) {\n\t\t\tshowLayer();\n\t\t} else {\n\t\t\thideLayer();\n\t\t}\n\t});\n\t\n\tsummaryLayer.focusin(function(event) {\n\t\tshowLayer();\n    });\n\tsummaryLayer.focusout(function(event) {\n\t\thideLayer();\n    });\n\n\tfunction showLayer () {\n\t\tsummaryLayer.addClass(\x27layer_open\x27);\n\t\tsummaryButton.attr(\x27aria-expanded\x27, true);\n\t\t$(window).on(\x27click\x27, checkLayer);\n\t}\n\n\tfunction hideLayer () {\n\t\tsummaryLayerStatus \x3d false;\n\t\tsummaryLayer.removeClass(\x27layer_open\x27);\n\t\tsummaryButton.attr(\x27aria-expanded\x27, false);\n\t}\n\n\tfunction checkLayer (ev) {\n\t\t\tif (summaryButton[0] \x3d\x3d ev.target || summaryButton[0].childNodes[0] \x3d\x3d ev.target) return false;\n\t\t\thideLayer();\n\t\t\t$(window).off(\x27click\x27, checkLayer);\n\t}\n})(jQuery);\n})(document.querySelectorAll(\x22.hcg_media_pc_cSub\x22));"));
#
# (0,eval("(function(elements){\n\n})(document.querySelectorAll(\x22.hcg_media_pc_head\x22));"));
#
# (0,eval("(function(elements){\n$(\x22.direct_link .btn_fold\x22).click(function() { \n\t$(\x22.direct_link\x22).toggleClass(\x22direct_open\x22);\n});\n\n})(document.querySelectorAll(\x22.hcg_media_pc_kakaoFoot\x22));"));
#
# (0,eval("(function(elements){\nvar kakaoWrap \x3d document.getElementById(\x27kakaoWrap\x27);\nvar categoryName \x3d $(elements).find(\x22.gnb_comm\x22).data(\x22category\x22);\ncategoryName \x3d window.layoutId \x3d\x3d \x27tvNews_pc\x27 ? \x27tv\x27 : categoryName;\n\n$(elements).find(\x22.gnb_comm li\x22).each(function() {\n  var $this \x3d $(this);\n  if($this.hasClass(categoryName)) {\n    $this.addClass(\x22on\x22).find(\x22.inner_bar\x22).css(\x22width\x22, \x22100%\x22);\n  }\n});\n\n//\uac80\uc0c9 suggest\n$.ajax({url:\x22https://s1.daumcdn.net/svc/original/U03/cssjs/pcSuggest/suggest-1.2.14.min.js\x22, cache:true, dataType:\x22script\x22}).done(function(){\n  var suggestInstance \x3d new suggest.Suggest(document.getElementById(\x22search_news\x22), {\n    inputEl: \x27qVal\x27,\n    suggestBoxEl: \x27suggestBox\x27,\n    autoFocus: \x27NORMAL\x27,\n    suggestLimit: 10,\n    isReverse: false,\n    searchURL: \x27https://search.daum.net/search\x27,\n    APIServer: {\n      host: \x27https://apihub.daum.net/suggest/v2/pc.json\x27,\n      queries: {\n        \x27mod\x27: \x27json\x27,\n        \x27code\x27: \x27utf_in_out\x27,\n        \x27appkey\x27 : \x279c97934ebab4c7e024c3a6e450ec195c\x27\n      }\n    }\n  });\n\n  // \ucd94\ucc9c \uac80\uc0c9\uc5b4 \ub9c8\uc6b0\uc2a4 \ud074\ub9ad\uc2dc \uac80\uc0c9\uc73c\ub85c \ubcf4\ub0b8\ub2e4.\n  suggestInstance.on(\x27click-item\x27, function () {\n    var $kakaoSearch \x3d $(\x27#kakaoSearch\x27);\n    $kakaoSearch.find(\x22input[name\x3d\x27DA\x27]\x22).val(\x2723B\x27);\n    $kakaoSearch.submit();\n  });\n\n  var queryInput \x3d $(\x22#qVal\x22);\n  queryInput.on(\x22focus\x22, function (e) {\n    e \x26\x26 e.preventDefault();\n    if (queryInput.val().length \x3e\x3d 0) {\n      queryInput.parent().addClass(\x22search_on\x22);\n    }\n  });\n  queryInput.on(\x22focusout\x22, function (e) {\n    e \x26\x26 e.preventDefault();\n    if (queryInput.val().length \x3d\x3d 0) {\n      queryInput.parent().removeClass(\x22search_on\x22);\n    }\n  });\n});\n\n})(document.querySelectorAll(\x22.hcg_media_pc_kakaoHead\x22));"));
#
# (0,eval("(function(elements){\n$(function(){\n    // click code\n    var click_codes \x3d [];\n    // GNB \n    click_codes.push({\n        \x22code\x22: \x22#logo\x22 , \x22selector\x22: \x22#kakaoHead \x3e div.head_media \x3e h1 \x3e a.link_daum\x22\n    });\n  \tclick_codes.push({\n        \x22code\x22: \x22#logo\x22 , \x22selector\x22: \x22.img_logo\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#gnb #default #service_news\x22 , \x22selector\x22: \x22#kakaoServiceLogo\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#gnb #default #service_enter\x22 , \x22selector\x22: \x22#kakaoRelServices \x3e li:nth-child(1) \x3e a\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#gnb #default #service_sports\x22 , \x22selector\x22: \x22#kakaoRelServices \x3e li:nth-child(2) \x3e a\x22\n    });\n  \tclick_codes.push({\n        \x22code\x22: \x22#gnb #default #service_lab\x22 , \x22selector\x22: \x22#kakaoRelServices \x3e li:nth-child(3) \x3e a\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#gnb #default #search\x22 , \x22selector\x22: \x22#kakaoBtnSearch\x22\n    });\n\n    click_codes.push({\n        \x22code\x22: \x22#media_home\x22 , \x22selector\x22: \x22.home \x3e a\x22\n    });\t\n    click_codes.push({\n        \x22code\x22: \x22#media_society\x22 , \x22selector\x22: \x22.society \x3e a\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#media_politics\x22 , \x22selector\x22: \x22.politics \x3e a\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#media_economic\x22 , \x22selector\x22: \x22.economic \x3e a\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#media_foreign\x22 , \x22selector\x22: \x22.foreign \x3e a\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#media_culture\x22 , \x22selector\x22: \x22.culture \x3e a\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#media_digital\x22 , \x22selector\x22: \x22.digital \x3e a\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#media_popular\x22 , \x22selector\x22: \x22.popular \x3e a\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#media_series\x22 , \x22selector\x22: \x22.series \x3e a\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#media_photo\x22 , \x22selector\x22: \x22.photo \x3e a\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#media_tv\x22 , \x22selector\x22: \x22.tv \x3e a\x22\n    });\n\n    // \uc678\ubd80 \uc11c\ube44\uc2a4 \ub9c1\ud06c\n    click_codes.push({\n        \x22code\x22: \x22#gnb #default #media_1boon\x22 , \x22selector\x22: \x22#kakaoGnb \x3e div \x3e div \x3e ul \x3e li:nth-child(1) \x3e a\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#gnb #default #media_funding\x22 , \x22selector\x22: \x22#kakaoGnb \x3e div \x3e div \x3e ul \x3e li:nth-child(2) \x3e a\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#gnb #default #widget_weather\x22 , \x22selector\x22: \x22#gnb_weather \x3e ul \x3e li \x3e a\x22\n    });\n\n    // \uae30\ub2a5 \uc601\uc5ed\n    click_codes.push({\n        \x22code\x22: \x22#util #widget_comment\x22 , \x22selector\x22: \x22#cSub .link_cmt\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#util #btn_summary\x22 , \x22selector\x22: \x22button.btn_summary\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#util #btn_share\x22 , \x22selector\x22: \x22button.btn_share\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#util #layer #facebook\x22 , \x22selector\x22: \x22a.link_fb\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#util #layer #kakaostory\x22 , \x22selector\x22: \x22a.link_ks\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#util #layer #twitter\x22 , \x22selector\x22: \x22a.link_tw\x22\n    });\n    click_codes.push({\n        \x22code\x22: \x22#util #layer #mail\x22 , \x22selector\x22: \x22a.link_mail\x22\n    });\n    click_codes.push( ...
#
# (0,eval("(function(elements){\n\n})(document.querySelectorAll(\x22.hcg_media_pc_mArticle\x22));"));
#
# (0,eval("(function(elements){\n\n})(document.querySelectorAll(\x22.hcg_media_pc_mAside\x22));"));
#
# (0,eval("(function(elements){\n\n})(document.querySelectorAll(\x22.hcg_media_pc_translation_status\x22));"));
#
#
#
#
#
#
#
# (0,eval("(function(){ \n//\ubbf8\ub2c8\ub2e4\uc74c\n$(function(){\n  window.minidaum_options \x3d { \n    enableLogoutRetun: true,\n    disableTracker: true\n  }\n\n  $.ajax({url:\x22https://go.daum.net/minidaum_pc.daum\x22,cache:\x22true\x22,dataType:\x22script\x22});\n});\n\n// \uad11\uace0\n$(function(){\n  var channel \x3d \x27harmony\x27;\n  var cp \x3d window.cpId + \x27_pc_media_news\x27;\n  $(\x27.daum_ddn_area\x27).attr(\x27data-ad-param-channel\x27, channel).attr(\x27data-ad-param-cp\x27, cp);\n  $.ajax({\n    url: \x22//t1.daumcdn.net/adfit/static/ad.min.js\x22,\n    cache: true,\n    dataType: \x22script\x22\n  });\n});\n\n// floating GNB \x26 Wing\n$(function () {\n  var $window \x3d $(window),\n      $cMain \x3d $(\x22#cMain\x22),\n      $kakaoWrap \x3d $(\x22#kakaoWrap\x22),\n      $kakaoGnb \x3d $(\x22#kakaoGnb\x22),\n      headHeight \x3d $(\x22#wrapMinidaum\x22).outerHeight() + $(\x22.head_media\x22).outerHeight(),\n      $mArticle \x3d $(\x22#mArticle\x22),\n      $mAside \x3d $(\x22#mAside\x22),\n      adFirst \x3d $(\x22.aside_ad:first\x22),\n      adLast \x3d $(\x22.aside_ad:last\x22),\n      cmNews \x3d $(\x22.cmt_news\x22),\n      $barProgress \x3d $(\x22#barProgress\x22),\n      // \ub0a0\uac1c \ud53d\uc2a4\ub4dc\uc778 \uacbd\uc6b0 left \uc704\uce58\ub97c \uc9c0\uc815\ud558\uae30 \uc704\ud574 \ud558\ub2e8 \uc2e4\uc2dc\uac04 \uac80\uc0c9\uc5b4\uc758 left \uac12\uc744 \uc774\uc6a9. \ub9cc\uc57d \uc5c6\uc73c\uba74 \uacc4\uc0b0\uc744 \ud55c\ub2e4.\n      realtimeAsideEl \x3d document.getElementById(\x27realtime_aside\x27);\n\n\n  var floatGnb \x3d function () {\n    if ($window.scrollTop() \x3e headHeight) {\n      var scrollPercent \x3d 100 * $window.scrollTop() / ($(document).height() - $window.height());\n      $kakaoWrap.addClass(\x22header_fixed\x22);\n      $barProgress.width(parseInt(scrollPercent, 10) + \x22%\x22);\n    } else {\n      $kakaoWrap.removeClass(\x22header_fixed\x22);\n    }\n  };\n\n  var floatWing \x3d function () {\n    var cMainWidth \x3d $cMain.width(),\n        mArticleWidth \x3d $mArticle.width(),\n        mAsideWidth \x3d $mAside.width(),\n        aSideGap \x3d cMainWidth - mArticleWidth - mAsideWidth,\n        leftOfRealtimeAside \x3d realtimeAsideEl ? (realtimeAsideEl.getBoundingClientRect().left \x3c 880 ? realtimeAsideEl.getBoundingClientRect().left + $(window).scrollLeft() : realtimeAsideEl.getBoundingClientRect().left ) :  mArticleWidth + aSideGap + parseInt($cMain.css(\x22marginLeft\x22), 10) - $window.scrollLeft(),\n        topPosition \x3d $window.scrollTop() - 8 - ($cMain.position().top + adFirst.height());\n\n    if($(\x22#mArticle\x22).outerHeight() \x3c $(\x22#mAside\x22).outerHeight())\n      return;\n\n    $(\x22.cmt_view\x22).css(\x22min-height\x22, \x22250px\x22);\n    if (topPosition \x3e 0) {\n      var articleHeight \x3d $mArticle.outerHeight() - cmNews.outerHeight();\n      var wingHeight \x3d $mAside.outerHeight() - adLast.outerHeight();\n      if (articleHeight \x3e (wingHeight + topPosition + 8)) {\n        $mAside.css({\n          \x22position\x22 : \x22fixed\x22,\n          \x22top\x22 : $kakaoGnb.height() - adFirst.outerHeight() - 74,\n          \x22left\x22 : parseInt(leftOfRealtimeAside, 10)\n        });\n      } else {\n        $mAside.css({\n          \x22position\x22 : \x22relative\x22,\n          \x22top\x22 : articleHeight - wingHeight,\n          \x22left\x22 : \x22inherit\x22\n        });\n      }\n    } else {\n      $mAside.css({\n        \x22position\x22 : \x22static\x22,\n        \x22top\x22 : \x22inherit\x22,\n        \x22left\x22 : \x22inherit\x22\n      });\n    }\n  };\n\n  $(window).on(\x22scroll\x22, function () {\n    floatGnb();\n    floatWing();\n  });\n\n  $(window).on(\x22resize\x22, function() {\n    floatWing();\n  });\n\n  floatGnb();\n  floatWing();\n\n});\n\n})();"));
#
# </script>
#  </body>
# </html>

# %% [markdown]
# ### post 요청하기
#    1. http post 요청하기
#    2. post data 이용하여 데이터 전달하기

# %%
url = 'https://portal.sejong.ac.kr/jsp/login/login_action.jsp'
data ={
    'id' : 1298432,
    'password': 1922940
}
resp = requests.post(url,data=data)
resp.text
# Out:
# "\n\n\n\n\n\n\n\n\n\n\n\n\r\n\r\n\r\n\r\n\r\n\r\n\n\n\n\n\n\n\n\r\n\r\n\r\n\r\n\n\r\n\n\r\n\r\n\n\n<script>document.location = 'login_noaccess.jsp';</script>"

# %% [markdown]
# ### HTTP header 데이터 이용하기
#    1. header 데이터 구성하기
#    2. header 데이터 전달하기

# %%
url = 'https://news.v.daum.net/v/20190728165812603'
headers ={
    'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.88 Safari/537.36'
}

resp = requests.get(url, headers = headers)
resp.text
# Out:
# '<!doctype html>\n<html lang="ko">\n <head> \n  <meta charset="utf-8"> \n  <meta http-equiv="X-UA-Compatible" content="IE=Edge"> \n  <meta name="referrer" content="always"> \n  <title>일론머스크 "테슬라에서 넷플릭스·유튜브 즐길 날 온다" | Daum 뉴스</title> \n  <link rel="shortcut icon" href="//m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico"> \n  <style>\n@charset "utf-8";@font-face{font-family:\'Nanum Myeongjo\';font-style:normal;font-weight:400;src:url(//t1.daumcdn.net/media/news/news2016/font/NanumMyeongjo-Regular.eot);src:url(//t1.daumcdn.net/media/news/news2016/font/NanumMyeongjo-Regular.eot?#iefix) format(\'embedded-opentype\'),url(//t1.daumcdn.net/media/news/news2016/font/NanumMyeongjo-Regular.woff2) format(\'woff2\'),url(//t1.daumcdn.net/media/news/news2016/font/NanumMyeongjo-Regular.woff) format(\'woff\'),url(//t1.daumcdn.net/media/news/news2016/font/NanumMyeongjo-Regular.ttf) format(\'truetype\')}body,div,dl,dt,dd,ul,ol,li,h1,h2,h3,h4,h5,h6,pre,code,form,fieldset,legend,textarea,p,blockquote,th,td,input,select,textarea,button{margin:0;padding:0}fieldset,img{border:0 none}dl,ul,ol,menu,li{list-style:none}blockquote,q{quotes:none}blockquote:before,blockquote:after,q:before,q:after{content:\'\';content:none}input,select,textarea,button{vertical-align:middle}input::-ms-clear{display:none}button{border:0 none;background-color:transparent;cursor:pointer}button::-moz-focus-inner{padding:0;border:0}body{min-width:980px;background:#fff}body,th,td,input,select,textarea,button{font-size:14px;line-height:1.5;font-family:AppleSDGothicNeo-Regular,\'Malgun Gothic\',\'맑은 고딕\',dotum,\'돋움\',sans-serif;color:#333;letter-spacing:-0.05em}a{color:#333;text-decoration:none}a:active,a:hover{text-decoration:underline}a:hover{color:#1e88e5}a:active{background-color:transparent}address,caption,cite,code,dfn,em,var{font-style:normal;font-weight:normal}.os_mac strong{font-weight:normal;font-family:AppleSDGothicNeo-Regular,sans-serif}html{overflow-y:scroll}#kakaoIndex{overflow:hidden;position:absolute;left:-9999px;width:0;height:1px;margin:0;padding:0}.ir_pm{display:block;overflow:hidden;font-size:0;line-height:0;text-indent:-9999px}.ir_wa{display:block;overflow:hidden;position:relative;z-index:-1;width:100%;height:100%}.screen_out{overflow:hidden;position:absolute;width:0;height:0;line-height:0;text-indent:-9999px}.show{display:block}.hide{display:none}.txt_newsview{display:block;overflow:hidden;font-size:0;line-height:0;background:url(//t1.daumcdn.net/media/common/newsview/txt_newsview_190618.png) 0 0 no-repeat;text-indent:-9999px;background-size:140px 750px}.ico_newsview{display:inline-block;overflow:hidden;font-size:0;line-height:0;background:url(//t1.daumcdn.net/media/common/newsview/ico_newsview_190327.png) 0 0 no-repeat;vertical-align:top;text-indent:-9999px;background-size:350px 350px}.ico_newsview2{background:url(//t1.daumcdn.net/media/common/newsview/ico_newsview2_180510.png) 0 0 no-repeat;background-size:50px 440px}.num_newsview{display:inline-block;overflow:hidden;font-size:0;line-height:0;background:url(//t1.daumcdn.net/media/common/newsview/num_newsview.png) 0 0 no-repeat;vertical-align:top;text-indent:-9999px;background-size:18px 600px}.link_cont,.link_thumb,.tit_g,.tit_thumb,.desc_thumb,.info_thumb{display:block}.link_thumb{position:relative}.link_thumb:before{position:absolute;top:0;left:0;right:0;bottom:0;z-index:10;border:1px solid #000;opacity:.05;content:\'\'}.link_thumb:after{position:absolute;top:0;left:0;right:0;bottom:0;background:transparent;opacity:0;-webkit-transition:background .2s,opacity .2s;transition:background .2s,opacity .2s;content:\'\'}.link_thumb:hover:after{background:#508dee;opacity:.45}.link_cont .wrap_thumb{display:block;position:relative}.link_cont .wrap_thumb:before{position:absolute;top:0;left:0;right:0;bottom:0;z-index:10;border:1px solid #000;opacity:.05;content:\'\'}.link_cont .wrap_thumb:after{position:absolute;top:0;left:0;right:0;bottom:0;background:transparent;opacity:0;-webkit-transition:background .2s,opacity .2s;tr ...

# %% [markdown]
# ### HTTP response 처리하기
#    1. response 객체의 이해
#    2. status_code 확인하기
#    3. text 속성 확인하기

# %%
url = 'https://news.v.daum.net/v/20190728165812603'
resp = requests.get(url)
if(resp.status_code ==200):
    print(resp.headers)
else:
    print('error')
# Out:
# {'Connection': 'close', 'Date': 'Sun, 05 Jan 2020 09:11:02 GMT', 'Set-Cookie': 'harmony_view_access_dt=1578215462697; Path=/', 'Expires': 'Thu, 01 Jan 1970 00:00:00 GMT', 'Content-Language': 'en-US', 'Content-Type': 'text/html;charset=utf-8', 'Vary': 'Accept-Encoding, User-Agent', 'Content-Encoding': 'gzip'}

# %% [markdown]
# ## 공공데이터 포털 OPEN API 사용하기
#    1. 공공데이터 포털 회원가입/로그인(https://www.data.go.kr/)
#    2. API 사용 요청 / 키 발급
#    3. API 문서(specification) 확인
#    4. API 테스트 및 개발

# %% [markdown]
# ### key 값 확인하기
#    - 서비스 호출 트래킹할 목적이나 악의적인 사용을 금지할 목적으로 주로 사용
#    - 새로 발급받은 키는 1시간 이후 사용 가능

# %%
key ='BhiaHK%2Fg9CtlYHPL%2Bx0djkA8nQi5Uc3psAnHKR2LFpTGWcz2pzwiQLDnoPr2CHW81Z6RYbxqr2oSak68KLjcxg%3D%3D'

# %% [markdown]
# ### Endpoint 확인하기
#    - API가 서비스되는 서버의 ip 혹은 domain 주소

# %%
#※지역코드 정보를 조회 (한페이지에 10개씩, 첫페이지를 조회)
endpoint = 'http://api.visitkorea.or.kr/openapi/service/rest/EngService/areaCode?serviceKey={}&numOfRows=10&pageSize=10&pageNo=1&MobileOS=ETC&MobileApp=AppTest&_type=json'.format(key)
print(endpoint)
# Out:
# http://api.visitkorea.or.kr/openapi/service/rest/EngService/areaCode?serviceKey=BhiaHK%2Fg9CtlYHPL%2Bx0djkA8nQi5Uc3psAnHKR2LFpTGWcz2pzwiQLDnoPr2CHW81Z6RYbxqr2oSak68KLjcxg%3D%3D&numOfRows=10&pageSize=10&pageNo=1&MobileOS=ETC&MobileApp=AppTest&_type=json

# %% [markdown]
# ### Parameter 확인하기
#    - API 호출에 필요한 parameter값 확인 및 구성

# %%
resp = requests.get(endpoint)
print(resp.status_code)
#print(resp.text)
type(resp.json())
data = resp.json() # key 지금 하나있음 response value 
print(data)
print(data['response']['body']['items']['item'][0])
# Out:
# 200
# {'response': {'header': {'resultCode': '0000', 'resultMsg': 'OK'}, 'body': {'items': {'item': [{'code': 1, 'name': 'Seoul', 'rnum': 1}, {'code': 2, 'name': 'Incheon', 'rnum': 2}, {'code': 3, 'name': 'Daejeon', 'rnum': 3}, {'code': 4, 'name': 'Daegu', 'rnum': 4}, {'code': 5, 'name': 'Gwangju', 'rnum': 5}, {'code': 6, 'name': 'Busan', 'rnum': 6}, {'code': 7, 'name': 'Ulsan', 'rnum': 7}, {'code': 8, 'name': 'Sejong', 'rnum': 8}, {'code': 31, 'name': 'Gyeonggi-do', 'rnum': 9}, {'code': 32, 'name': 'Gangwon-do', 'rnum': 10}]}, 'numOfRows': 10, 'pageNo': 1, 'totalCount': 17}}}
# {'code': 1, 'name': 'Seoul', 'rnum': 1}

# %% [markdown]
# ### 요청 및 Response 확인
#    - requests 모듈을 활용하여 API호출
#    - response 확인하여 원하는 정보 추출
#    - json 데이터의 경우, python dictionary로 변경하여 사용가능

# %%
endpoint='http://api.visitkorea.or.kr/openapi/service/rest/EngService/searchStay?serviceKey={}&numOfRows=10&pageSize=10&pageNo=1&MobileOS=ETC&MobileApp=AppTest&listYN=Y&arrange=A&goodStay=1&_type=json'.format(key)
print(endpoint)
resp = requests.get(endpoint)
data = resp.json()
#print(data)
print(data['response']['body']['items']['item'][0]['addr1'])
#print(data['response']['body']['items']['item'][1])
# Out:
# http://api.visitkorea.or.kr/openapi/service/rest/EngService/searchStay?serviceKey=BhiaHK%2Fg9CtlYHPL%2Bx0djkA8nQi5Uc3psAnHKR2LFpTGWcz2pzwiQLDnoPr2CHW81Z6RYbxqr2oSak68KLjcxg%3D%3D&numOfRows=10&pageSize=10&pageNo=1&MobileOS=ETC&MobileApp=AppTest&listYN=Y&arrange=A&goodStay=1&_type=json
# 3rd floor, 26, Eulji-ro 9-gil, Jung-gu, Seoul

# %% [markdown]
# ##  html 문자열 파싱
#    - 문자열로 정의된 html 데이터 파싱하기

# %% [markdown]
# 1. beautifulsoup 모듈 사용하기

# %%
from bs4 import BeautifulSoup

# %%
html ='''
<html>
    <head>
        <title>BeautifulSoup test</test>
    </head>
    <body>
        <div id='upper' class='test' custom ='good'>
            <h3 title ='Good Content Title'>Contents Title</h3>
            <p>Test contents</p>
        </div>
        <div id='lower' class='test' custom='nice'>
            <p>Test Test TEST</p>
            <p>Test Test TEST</p>
            <p>Test Test TEST</p>
        </div>
    </body>
</html>                       v '''

# %% [markdown]
# ### find 함수
#    - 특정 html tag를 검색
#    - 검색 조건을 명시하여 찾고자하는 tag를 검색

# %%
soup = BeautifulSoup(html)
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
soup.find('h3')
# Out:
# <h3 title="Good Content Title">Contents Title</h3>

# %%
soup.find('p') # 가장 첫번째 tag만 리턴한다
# Out:
# <p>Test contents</p>

# %%
soup.find('div') #upper만 찾음
# Out:
# <div class="test" custom="good" id="upper">
# <h3 title="Good Content Title">Contents Title</h3>
# <p>Test contents</p>
# </div>

# %%
soup.find('div', custom='nice')
# Out:
# <div class="test" custom="nice" id="lower">
# <p>Test Test TEST</p>
# <p>Test Test TEST</p>
# <p>Test Test TEST</p>
# </div>

# %%
soup.find('div', id='lower')
# Out:
# <div class="test" custom="nice" id="lower">
# <p>Test Test TEST</p>
# <p>Test Test TEST</p>
# <p>Test Test TEST</p>
# </div>

# %%
soup.find('div', id='upper')
# Out:
# <div class="test" custom="good" id="upper">
# <h3 title="Good Content Title">Contents Title</h3>
# <p>Test contents</p>
# </div>

# %%
soup.find('div', class_='test')  # 에러 class_를 붙여야함
# Out:
# <div class="test" custom="good" id="upper">
# <h3 title="Good Content Title">Contents Title</h3>
# <p>Test contents</p>
# </div>

# %%
attrs = {'id':'upper','class':'test'} # attrs(attributes)
soup.find('div', attrs= attrs)
# Out:
# <div class="test" custom="good" id="upper">
# <h3 title="Good Content Title">Contents Title</h3>
# <p>Test contents</p>
# </div>

# %% [markdown]
# ### find_all 함수
#    - find가 조건에 만족하는 하나의 tag만 검색한다면, find_all은 조건에 맞는 모든 tag를 **리스트**로 반환

# %%
soup.find_all('div',class_='test') # 리스트로 반환
# Out:
# [<div class="test" custom="good" id="upper">
#  <h3 title="Good Content Title">Contents Title</h3>
#  <p>Test contents</p>
#  </div>, <div class="test" custom="nice" id="lower">
#  <p>Test Test TEST</p>
#  <p>Test Test TEST</p>
#  <p>Test Test TEST</p>
#  </div>]

# %% [markdown]
# ### get_text 함수
#    - tag안의 value를 추출
#    - 부모tag의 경우, 모든 자식 tag의 value를 추출

# %%
tag = soup.find('h3')
tag.get_text()
# Out:
# 'Contents Title'

# %%
tag = soup.find('p')
tag.get_text()
# Out:
# 'Test contents'

# %%
tag = soup.find('div',id='upper')
print(tag)
tag.get_text()
# Out:
# <div class="test" custom="good" id="upper">
# <h3 title="Good Content Title">Contents Title</h3>
# <p>Test contents</p>
# </div>
# '\nContents Title\nTest contents\n'

# %%
tag.get_text().strip()
# strip() 문자열 양쪽에 있는 한 칸 이상의 연속된 공백을 모두 지운다.
# Out:
# 'Contents Title\nTest contents'

# %% [markdown]
# ### attribute 값 추출하기
#    - 경우에 따라 추출하고자 하는 값이 attribute에도 존재함
#    - 이 경우에는 검색한 tag에 attribute 이름을[]연산을 통해 추출가능
#    - 예) div.find('h3)['title']

# %%
tag = soup.find('h3')
print(tag)
title = tag['title']
print(title)
# Out:
# <h3 title="Good Content Title">Contents Title</h3>
# Good Content Title

# %% [markdown]
# ### id, class 속성을 이용하여 원하는 값 추출하기

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### 다음 뉴스 데이터 추출
#
#    - 뉴스기사에서 제목, 작성자, 작성일, 댓글 개수 추출
#    - [뉴스링크](https://news.v.daum.net/v/20190728165812603)
#    - tag를 추출할때는 가장 그 tag를 쉽게 특정할 수 있는 속성을 사용
#        - id의 경우 원칙적으로 한 html 문서 내에서 유일

# %% [markdown]
# <h3 class="tit_view" data-translation="">일론머스크 "테슬라에서 넷플릭스·유튜브 즐길 날 온다"</h3>

# %% [markdown]
# <span class="info_view">
#     <span class="txt_info">이민우</span>
#     <span class="txt_info">입력 2019.07.28. 16:58</span>
#     <button id="alexCounter" class="emph_g2 link_cmt #util #widget_comment" style="cursor: pointer;">댓글
#     <span class="alex-count-area">42</span>개</button>
# </span>

# %% [markdown]
# #### find_all 함수를 사용할 경우

# %%
url = 'https://news.v.daum.net/v/20190728165812603'
resp = requests.get(url)

def return_name(x):    
    return x.get_text()

soup = BeautifulSoup(resp.text)
title = soup.find('h3',class_='tit_view').get_text()
name_tag = soup.find_all('span',class_='txt_info') # 리스트 반환 tag형
name_list = list(map(return_name,name_tag))
print(title)
print(name_list)
# Out:
# 일론머스크 "테슬라에서 넷플릭스·유튜브 즐길 날 온다"
# ['이민우', '입력 2019.07.28. 16:58']

# %% [markdown]
# #### 중접 find 함수
#    - find 한 태그가 많은 정보를 함유하고 있을때

# %%
url = 'https://news.v.daum.net/v/20190728165812603'
resp = requests.get(url)

soup = BeautifulSoup(resp.text)

block = soup.find('span', class_='info_view')

name = block.find('span',class_='txt_info')
name
# Out:
# <span class="txt_info">이민우</span>

# %%
url = 'https://news.v.daum.net/v/20190728165812603'
resp = requests.get(url)
soup = BeautifulSoup(resp.text)
container = soup.find('div',id='harmonyContainer')
contents =''
for p in container.find_all('p'):
    contents += p.get_text()
print(contents)
# Out:
# [아시아경제 이민우 기자] 일론 머스크 테슬라 최고경영자(CEO)가 자사 전기 자동차 모델에 넷플릭스와 유튜브 등 온라인동영상서비스(OTT)를 탑재할 것이라고 예고했다. 단순히 자율 주행 전기차가 단순히 주행을 위한 정보를 알려주는 것을 넘어 각종 영상 콘텐츠를 즐기는 공간으로도 확장하겠다는 전략으로 풀이된다.27일(현지시간) 더버지 등 주요 외신들에 따르면 머스크 CEO는 자신의 트위터를 통해 이 같은 계획을 밝혔다. 그는 "자동차가 정차했을 때 넷플릭스와 유튜브를 감상할 수 있는 기능이 조만간 추가될 것"이라며 "편안한 좌석과 서라운드 사운드 오디오를 통해 영화관과 같은 느낌을 받을 수 있을 것"이라고 강조했다.테슬라가 이처럼 콘텐츠 방면으로 확장하려 든 것은 이번이 처음이 아니다. 지난달 세계 최대 게임쇼 E3에서는 이미 운전자가 '폴아웃 쉘터'라는 게임을 할 수 있을 것이라고 발표한 바 있다. 이후에도 최근 게임업체 아타리사(社)의 자동차 경주 게임 ‘폴포지션’, 슈팅게임 ‘템페스트’, ‘미사일커맨드’ 등 고전 게임을 제공하기도 했다. 운전대로 게임을 조작하는 방식으로, 차가 주차돼 있을 경우에만 즐길 수 있다.이번 영상 콘텐츠는 주행 중에도 감상할 수 있도록 하는 방안을 고려하고 있다. 테슬라 측은 규제당국이 자율주행에 대해 완전히 승인하면 차량이 움직일 때에도 승객이 동영상을 즐길 수 있을 것이라고 설명했다.하지만 아직까지 자율주행차의 안전에 대한 우려는 완전히 걷혀지지 않은 상황이다. 지난 2017년 차량공유 서비스 우버의 자율주행 시범차량이 보행자와 충돌한 사고가 발생한 바 있다. 게다가 당시 시험 운전자는 디즈니의 동영상 스트리밍 서비스인 '훌루'를 이용하고 있던 것으로 밝혀졌다.이민우 기자 letzwin@asiae.co.kr

# %% [markdown]
# ### - CSS를 이용하여 tag 찾기
#    - select, select_one 함수 사용
#    - css selector 사용법
#        - 태그명 찾기 tag
#        - 자손 태그 찾기 - 자손 관계(tag tag)
#        - 자식 태그 찾기 - 다이렉트 자식 관계(tag > tag)
#        - 아이디 찾기 #id
#        - 클래스 찾기 .class
#        - 속성값 찾기 [name = 'test']
#            - 속성값 prefix 찾기 [name ^='test]
#            - 속성값 suffix 찾기 [name $='test']
#            - 속성값 substring 찾기 [name *='test]
#        - n 번째 자식 tag 찾기 :nth-child(n)

# %%
url = 'https://news.v.daum.net/v/20190728165812603'
resp = requests.get(url)
soup = BeautifulSoup(resp.text)
soup.select('h3')
# Out:
# [<h3 class="tit_view" data-translation="">일론머스크 "테슬라에서 넷플릭스·유튜브 즐길 날 온다"</h3>,
#  <h3 class="txt_newsview" data-reactid=".14bwskiph71.0">많이본 뉴스</h3>,
#  <h3 class="txt_newsview">포토&amp;TV</h3>,
#  <h3 class="txt_newsview">실시간 이슈</h3>,
#  <h3 class="txt_newsview">이 시각 추천뉴스</h3>,
#  <h3 class="txt_newsview">실시간 주요이슈</h3>]

# %%
url = 'https://news.v.daum.net/v/20190728165812603'
resp = requests.get(url)
soup = BeautifulSoup(resp.text)
soup.select('h3')
# Out:
# [<h3 class="tit_view" data-translation="">일론머스크 "테슬라에서 넷플릭스·유튜브 즐길 날 온다"</h3>,
#  <h3 class="txt_newsview" data-reactid=".20bvt3slma0.0">많이본 뉴스</h3>,
#  <h3 class="txt_newsview">포토&amp;TV</h3>,
#  <h3 class="txt_newsview">실시간 이슈</h3>,
#  <h3 class="txt_newsview">이 시각 추천뉴스</h3>,
#  <h3 class="txt_newsview">실시간 주요이슈</h3>]

# %%
url = 'https://news.v.daum.net/v/20190728165812603'
resp = requests.get(url)
soup = BeautifulSoup(resp.text)
soup.select('div#harmonyContainer  p') 
#div 태그 id harmonyContainer 아래 존재한 모든 p 태그
# Out:
# [<p class="link_figure"><img alt="일론 머스크 테슬라 최고경영자(CEO) [이미지출처=로이터연합뉴스]" class="thumb_g_article" dmcf-mid="NBMY3ZZhN4" dmcf-mtype="image" height="366" src="https://t1.daumcdn.net/news/201907/28/akn/20190728165813230vjsq.jpg" width="550"/></p>,
#  <p>[아시아경제 이민우 기자] 일론 머스크 테슬라 최고경영자(CEO)가 자사 전기 자동차 모델에 넷플릭스와 유튜브 등 온라인동영상서비스(OTT)를 탑재할 것이라고 예고했다. 단순히 자율 주행 전기차가 단순히 주행을 위한 정보를 알려주는 것을 넘어 각종 영상 콘텐츠를 즐기는 공간으로도 확장하겠다는 전략으로 풀이된다.</p>,
#  <p>27일(현지시간) 더버지 등 주요 외신들에 따르면 머스크 CEO는 자신의 트위터를 통해 이 같은 계획을 밝혔다. 그는 "자동차가 정차했을 때 넷플릭스와 유튜브를 감상할 수 있는 기능이 조만간 추가될 것"이라며 "편안한 좌석과 서라운드 사운드 오디오를 통해 영화관과 같은 느낌을 받을 수 있을 것"이라고 강조했다.</p>,
#  <p class="link_figure"><img alt="(출처=일론 머스크 트위터 계정 캡쳐)" class="thumb_g_article" dmcf-mid="NRhnb5SRpx" dmcf-mtype="image" height="352" src="https://t1.daumcdn.net/news/201907/28/akn/20190728165813670hwxf.png" width="550"/></p>,
#  <p>테슬라가 이처럼 콘텐츠 방면으로 확장하려 든 것은 이번이 처음이 아니다. 지난달 세계 최대 게임쇼 E3에서는 이미 운전자가 '폴아웃 쉘터'라는 게임을 할 수 있을 것이라고 발표한 바 있다. 이후에도 최근 게임업체 아타리사(社)의 자동차 경주 게임 ‘폴포지션’, 슈팅게임 ‘템페스트’, ‘미사일커맨드’ 등 고전 게임을 제공하기도 했다. 운전대로 게임을 조작하는 방식으로, 차가 주차돼 있을 경우에만 즐길 수 있다.</p>,
#  <p>이번 영상 콘텐츠는 주행 중에도 감상할 수 있도록 하는 방안을 고려하고 있다. 테슬라 측은 규제당국이 자율주행에 대해 완전히 승인하면 차량이 움직일 때에도 승객이 동영상을 즐길 수 있을 것이라고 설명했다.</p>,
#  <p>하지만 아직까지 자율주행차의 안전에 대한 우려는 완전히 걷혀지지 않은 상황이다. 지난 2017년 차량공유 서비스 우버의 자율주행 시범차량이 보행자와 충돌한 사고가 발생한 바 있다. 게다가 당시 시험 운전자는 디즈니의 동영상 스트리밍 서비스인 '훌루'를 이용하고 있던 것으로 밝혀졌다.</p>,
#  <p dmcf-pid="NUOWg8Qxyd" dmcf-ptype="general">이민우 기자 letzwin@asiae.co.kr</p>]

# %%
url = 'https://news.v.daum.net/v/20190728165812603'
resp = requests.get(url)
soup = BeautifulSoup(resp.text)
soup.select('h3.tit_view') 
soup.select('.tit_view')
# Out:
# [<h3 class="tit_view" data-translation="">일론머스크 "테슬라에서 넷플릭스·유튜브 즐길 날 온다"</h3>]

# %%
soup.select('h3[class = "tit_view"]')
# Out:
# [<h3 class="tit_view" data-translation="">일론머스크 "테슬라에서 넷플릭스·유튜브 즐길 날 온다"</h3>]

# %%
soup.select('h3[class ^= "tx"]') # tx로 시작하는 부분 문자열
# Out:
# [<h3 class="txt_newsview" data-reactid=".1ug9h8fyp17.0">많이본 뉴스</h3>,
#  <h3 class="txt_newsview">포토&amp;TV</h3>,
#  <h3 class="txt_newsview">실시간 이슈</h3>,
#  <h3 class="txt_newsview">이 시각 추천뉴스</h3>,
#  <h3 class="txt_newsview">실시간 주요이슈</h3>]

# %%
soup.select('h3[class $= "_view"]') # _view로 끝나는 부분 문자열
# Out:
# [<h3 class="tit_view" data-translation="">일론머스크 "테슬라에서 넷플릭스·유튜브 즐길 날 온다"</h3>]

# %%
soup.select('h3[class *= "_"]') # _이 있는 부분 문자열
# Out:
# [<h3 class="tit_view" data-translation="">일론머스크 "테슬라에서 넷플릭스·유튜브 즐길 날 온다"</h3>,
#  <h3 class="txt_newsview" data-reactid=".1ug9h8fyp17.0">많이본 뉴스</h3>,
#  <h3 class="txt_newsview">포토&amp;TV</h3>,
#  <h3 class="txt_newsview">실시간 이슈</h3>,
#  <h3 class="txt_newsview">이 시각 추천뉴스</h3>,
#  <h3 class="txt_newsview">실시간 주요이슈</h3>]

# %%
soup.select('span.txt_info:nth-child(1)')
# Out:
# [<span class="txt_info">이민우</span>]

# %% [markdown]
# #### - 정규표현식으로 tag 찾기

# %%
import re
soup.find_all(re.compile('h\d'))
# Out:
# [<h1> <a class="link_daum" href="https://www.daum.net/"> <img alt="Daum" class="thumb_g" height="19" src="//t1.daumcdn.net/media/news/news2016/retina/logo_daum.jpg" width="45"/> </a> <a href="https://media.daum.net/" id="kakaoServiceLogo"><span class="ir_wa">뉴스</span></a> </h1>,
#  <h2 class="screen_out">검색</h2>,
#  <h2 class="screen_out">뉴스 메인메뉴</h2>,
#  <h2 class="screen_out" id="kakaoBody">IT</h2>,
#  <h3 class="tit_view" data-translation="">일론머스크 "테슬라에서 넷플릭스·유튜브 즐길 날 온다"</h3>,
#  <h3 class="txt_newsview" data-reactid=".1ug9h8fyp17.0">많이본 뉴스</h3>,
#  <h3 class="txt_newsview">포토&amp;TV</h3>,
#  <h3 class="txt_newsview">실시간 이슈</h3>,
#  <h3 class="txt_newsview">이 시각 추천뉴스</h3>,
#  <h3 class="txt_newsview">실시간 주요이슈</h3>,
#  <h2 class="tit_direct">바로가기</h2>,
#  <h2 class="screen_out">서비스 이용정보</h2>]

# %%
#soup.find_all('img')
soup.find_all('img', attrs = {'src':re.compile('.+\.\w\w\w')})
# Out:
# [<img alt="Daum" class="thumb_g" height="19" src="//t1.daumcdn.net/media/news/news2016/retina/logo_daum.jpg" width="45"/>,
#  <img alt="아시아경제" class="thumb_g" src="https://t1.daumcdn.net/media/news/news2016/cp/cp_akn.gif"/>,
#  <img alt="일론 머스크 테슬라 최고경영자(CEO) [이미지출처=로이터연합뉴스]" class="thumb_g_article" dmcf-mid="NBMY3ZZhN4" dmcf-mtype="image" height="366" src="https://t1.daumcdn.net/news/201907/28/akn/20190728165813230vjsq.jpg" width="550"/>,
#  <img alt="(출처=일론 머스크 트위터 계정 캡쳐)" class="thumb_g_article" dmcf-mid="NRhnb5SRpx" dmcf-mtype="image" height="352" src="https://t1.daumcdn.net/news/201907/28/akn/20190728165813670hwxf.png" width="550"/>,
#  <img alt="발언하는 황교안" class="thumb_g" src="https://img1.daumcdn.net/thumb/S288x280.q70/?fname=https://t1.daumcdn.net/news/202001/06/yonhap/20200106154232296olbc.jpg"/>,
#  <img alt="100일 앞으로 다가온 선거..4·15 총선 관전 포인트는?" class="thumb_g" src="https://img1.daumcdn.net/thumb/S288x280.q70/?fname=https://t1.daumcdn.net/news/202001/06/sbsi/20200106154232388jonl.jpg"/>,
#  <img alt="" class="thumb_g" height="54" src="https://img1.daumcdn.net/thumb/S168x108.q70/?fname=https://t1.daumcdn.net/news/202001/06/yonhap/20200106141402423timf.jpg" width="84"/>,
#  <img alt="" class="thumb_g" height="54" src="https://img1.daumcdn.net/thumb/S168x108.q70/?fname=https://t1.daumcdn.net/news/202001/06/yonhap/20200106110432827tozo.jpg" width="84"/>,
#  <img alt="" class="thumb_g" height="54" src="https://img1.daumcdn.net/thumb/S168x108.q70/?fname=https://t1.daumcdn.net/news/202001/06/yonhap/20200106152532546soyt.jpg" width="84"/>]

# %%
soup.find_all('h3', class_ = re.compile('.+view$'))
# Out:
# [<h3 class="tit_view" data-translation="">일론머스크 "테슬라에서 넷플릭스·유튜브 즐길 날 온다"</h3>,
#  <h3 class="txt_newsview" data-reactid=".1ug9h8fyp17.0">많이본 뉴스</h3>,
#  <h3 class="txt_newsview">포토&amp;TV</h3>,
#  <h3 class="txt_newsview">실시간 이슈</h3>,
#  <h3 class="txt_newsview">이 시각 추천뉴스</h3>,
#  <h3 class="txt_newsview">실시간 주요이슈</h3>]

# %%
soup.find('span', class_='alex-count-area') # 0이 왜 나올까?
# Out:
# <span class="alex-count-area">0</span>

# %% [markdown]
# ### 사이트에 로그인해서 데이터 클롤링

# %% [markdown]
# #### 다음 뉴스 댓글 개수 크롤링하기

# %%
import requests

# %% [markdown]
# #### HTTP 상태코드
#    - 1xx(정보): 요청을 받았으며 프로세스를 계속한다
#    - 2xx(성공): 요청을 성공적으로 받았으며 인식했고 수용하였다
#    - 3xx(리다이렉션): 요청 완료를 위해 추가 작업 조치가 필요하다
#    - 4xx(클라이언트 오류): 요청의 문법이 잘못되었거나 요청을 처리할 수 없다
#    - 5xx(서버 오류): 서버가 명백히 유효한 요청에 대해 충족을 실패했다

# %% [markdown]
# 헤더를 dict로 구성하면 호출 가능성 증가

# %%
url = 'https://comment.daum.net/apis/v1/posts/@20190728165812603'

# %%
headers = {'Authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....g2ov6X_NvD0E8MJe7xZMGi5yh1rCHRF0penkwCB3W-M',
            'Origin' : 'https://news.v.daum.net' ,
            'Referer' : 'https://news.v.daum.net/v/20190728165812603',
           'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.88 Safari/537.36'
          }
resp = requests.get(url,headers = headers)
resp.json()['commentCount']
# Out:
# 42

# %% [markdown]
# ### 로그인하여 데이터 크롤링하기
#    - 특정한 경우, 로그인을 해서 크롤링을 해야함 하는 경우가 존재
#    - 예) 쇼핑몰에서 주문한 아이템 목록, 마일리지 조회 등
#    - 이 경우, 로그인을 자동화 하고 로그인에 사용한 세션을 유지하여 크롤링을 진행
